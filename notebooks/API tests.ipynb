# %%
# %load_ext autoreload
# %autoreload 2

# %%
from fydjob.NLPFrame import NLPFrame
df = NLPFrame().df
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     /Users/alexanderherdt/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     /Users/alexanderherdt/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /Users/alexanderherdt/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# Loaded from /Users/alexanderherdt/code/mizzle-toe/find-your-dream-job/fydjob/output/nlp_frame.joblib

# %%
df_dict = df.head(5).to_dict()
pd.DataFrame(df_dict)
# Out:
#    job_id                                   job_title  \
# 0       1  Data Scientist / Matching Engineer (m/w/d)
# 1       2    Senior Software Engineer - Data Platform
# 2       3                Senior Data Engineer (m/w/t)
# 3       4                       Data Engineer (w/m/d)
# 4       5                               Data Engineer
#
#                                             job_text          company  \
# 0  You are responsible for improvement of Taledo’...           Taledo
# 1  We are looking for a Senior Software Engineer ...       Zalando SE
# 2  As a member of the Data Engineering Team, you ...     Quandoo GmbH
# 3  We are digitty.io – an international start-up ...       digitty.io
# 4  We activate data for our clients by using stat...  Gemma Analytics
#
#   location                                           job_info job_link  \
# 0   Berlin  Data Scientist / Matching Engineer (m/w/d)\nTa...     NULL
# 1   Berlin  Senior Software Engineer - Data Platform\nZala...     NULL
# ...

# %%
import requests
url = "http://127.0.0.1:8000/"
skills = "skills"


response = requests.get(url, params = params)
### get the data frame from the api
pd.DataFrame(response.json())
# Out:
#       job_id                                   job_title  \
# 0          1  Data Scientist / Matching Engineer (m/w/d)
# 1          2    Senior Software Engineer - Data Platform
# 2          3                Senior Data Engineer (m/w/t)
# 3          4                       Data Engineer (w/m/d)
# 4          5                               Data Engineer
# ...      ...                                         ...
# 5876    5877                   Manager, Machine Learning
# 5877    5878               Lead Data Scientist - Haskell
# 5878    5879            Senior Data Scientist (GEC11902)
# 5879    5880             Senior Data & Applied Scientist
# 5880    5881     Principal Data Scientist, Deep Learning
#
#                                                job_text          company  \
# 0     You are responsible for improvement of Taledo’...           Taledo
# 1     We are looking for a Senior Software Engineer ...       Zalando SE
# ...

# %%
params = {"query": ["python , MaTh"],
         "number": 10}

response2 = requests.get(url+skills, params = params)
response2.json()
# Out:
# ---------------------------------------------------------------------------
# ConnectionRefusedError                    Traceback (most recent call last)
# ~/.pyenv/versions/3.8.6/envs/fydjob/lib/python3.8/site-packages/urllib3/connection.py in _new_conn(self)
#     168         try:
# --> 169             conn = connection.create_connection(
#     170                 (self._dns_host, self.port), self.timeout, **extra_kw
#
# ~/.pyenv/versions/3.8.6/envs/fydjob/lib/python3.8/site-packages/urllib3/util/connection.py in create_connection(address, timeout, source_address, socket_options)
#      95     if err is not None:
# ---> 96         raise err
#      97
#
# ~/.pyenv/versions/3.8.6/envs/fydjob/lib/python3.8/site-packages/urllib3/util/connection.py in create_connection(address, timeout, source_address, socket_options)
#      85                 sock.bind(source_address)
# ---> 86             sock.connect(sa)
#      87             return sock
#
# ...

# %%
from fydjob.Word2VecPipeline import Word2VecPipeline

pipe = Word2VecPipeline()

pipe.most_similar("python",10)
# Out:
# Starting Word2Vec...
# Loaded model from /Users/alexanderherdt/code/mizzle-toe/find-your-dream-job/fydjob/data/models/w2v_model_baseline.model
# [('r', 0.9589256644248962),
#  ('scala', 0.9507297277450562),
#  ('languages', 0.9489396214485168),
#  ('java', 0.9475581049919128),
#  ('programing', 0.9394864439964294),
#  ('perl', 0.9299498796463013),
#  ('matlab', 0.9242859482765198),
#  ('programming', 0.9236627221107483),
#  ('r.', 0.9223112463951111),
#  ('php', 0.9221781492233276)]

# %%
pipe.most_similar("mathematics")
# Out:
# [('statistics', 0.966637134552002),
#  ('math', 0.9631338119506836),
#  ('physics', 0.9472707509994507),
#  ('computer', 0.9361725449562073),
#  ('science', 0.9309971332550049),
#  ('economics', 0.925482988357544),
#  ('scienceengineering', 0.9140040874481201),
#  ('econometrics', 0.9105654358863831),
#  ('fields', 0.9079679250717163),
#  ('applied', 0.9071071147918701)]
