# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_json("../raw_data/glassdoor_scraper_output/data_scientist_in_berlin_2020-09-03.json")

# %%
df.head(5)
# Out:
#                                             position  \
# 0                             Data Scientist (m/f/x)
# 1  Studentische Aushilfe (m/w/d) Data Science im ...
# 2         Data Architect (m/w/d) - Energy Management
# 3              Data Scientist Bioinformatics (m/f/d)
# 4                                     Data Scientist
#
#                                   company  \
# 0                Deutsche Bank AG\n3.6\n★
# 1  Federal Association of the AOK\n3.9\n★
# 2     Viessmann Werke Berlin Gmbh\n4.0\n★
# 3                    Centogene AG\n2.2\n★
# 4                    Marley Spoon\n4.0\n★
#
#                                          description  \
# 0  Job Description:\n\n\nTG 8\n\nDetails of the r...
# 1  Vielfältige Aufgaben warten auf Sie\nUnterstüt...
# 2  What gets you out of bed in the morning and ke...
# 3  Welcome at CENTOGENE!\n\nWe, CENTOGENE GmbH ("...
# 4  Marley Spoon is the new way to cook. We bring ...
#
#                                                  url
# 0  https://www.glassdoor.de/job-listing/data-scie...
# 1  https://www.glassdoor.de/job-listing/studentis...
# 2  https://www.glassdoor.de/job-listing/data-arch...
# 3  https://www.glassdoor.de/job-listing/data-scie...
# 4  https://www.glassdoor.de/job-listing/data-scie...

# %% [markdown]
# ## Preprocessing

# %%
# Out:
# (216, 5)

# %%
## change case to lower
def to_lower(text):
    return text.lower()
df["clean"] = df["description"].apply(to_lower)

# %%
## remove numbers from the corpus
def remove_number(text):
    text = ''.join(word for word in text if not word.isdigit())
    
    return text

df["clean"]= df["clean"].apply(remove_number)

# %%
import string

## remove special puncutation from text
def remove_punctuation(text):
    for punctuation in string.punctuation:
        text = text.replace(punctuation, '')
    
    return text

df["clean"] = df["clean"].apply(remove_punctuation)

# %%
## tag the language of the dataframe
from time import sleep
from langdetect import detect

def tag_language(text):
    ln = detect(text)
    
    return ln

df["language"] = df["clean"].apply(tag_language)
# Out:
# 0      job description\n\n\ntg \n\ndetails of the rol...
# 1      vielfältige aufgaben warten auf sie\nunterstüt...
# 2      what gets you out of bed in the morning and ke...
# 3      welcome at centogene\n\nwe centogene gmbh cent...
# 4      marley spoon is the new way to cook we bring d...
#                              ...
# 297    stenon is the world’s first realtime soil anal...
# 298    what gets you out of bed in the morning and ke...
# 299    we are hiring\n\nat permacon you will find the...
# 300    department offprice data science\n\nreports to...
# 301    executive principal data engineer  digital fou...
# Name: clean, Length: 302, dtype: object

# %%
## remove stopwords and tokenize the text
from nltk.corpus import stopwords 
from nltk.tokenize import word_tokenize

def remove_stopwords(text):

    stop_words = set(stopwords.words('english')) 

    word_tokens = word_tokenize(text) 
  
    text = [w for w in word_tokens if not w in stop_words] 
  
    return text


df["clean"] = df["clean"].apply(remove_stopwords)

# %%
## lemmatize the output
from nltk.stem import WordNetLemmatizer

def lemmatize_words(text):
    
    lemmatizer = WordNetLemmatizer()

    lemmatized = [lemmatizer.lemmatize(word) for word in text]

    return lemmatized

df["clean"] = df["clean"].apply(lemmatize_words)

# %%
df[df["language"] == "en"]
# Out:
#                                             position  \
# 0                             Data Scientist (m/f/x)
# 2         Data Architect (m/w/d) - Energy Management
# 3              Data Scientist Bioinformatics (m/f/d)
# 4                                     Data Scientist
# 5                                     Data Scientist
# ..                                               ...
# 297                     Senior Data Engineer (m/f/d)
# 298       Data Architect (m/w/d) - Energy Management
# 299                         Senior scientist (m/f/d)
# 300  Software Engineer for Algorithmic Data Products
# 301                Executive Principal Data Engineer
#
#                                  company  \
# 0               Deutsche Bank AG\n3.6\n★
# 2    Viessmann Werke Berlin Gmbh\n4.0\n★
# 3                   Centogene AG\n2.2\n★
# 4                   Marley Spoon\n4.0\n★
# 5                         Quantum Brains
# ..                                   ...
# 297                          stenon GmbH
# 298                 00 - Viessmann Group
# 299                Permacon GmbH\n1.9\n★
# 300                      Zalando\n3.5\n★
# 301                      Zalando\n3.5\n★
#
#                                            description  \
# 0    Job Description:\n\n\nTG 8\n\nDetails of the r...
# 2    What gets you out of bed in the morning and ke...
# 3    Welcome at CENTOGENE!\n\nWe, CENTOGENE GmbH ("...
# 4    Marley Spoon is the new way to cook. We bring ...
# 5    Responsibilities (include but not limited to t...
# ..                                                 ...
# 297  stenon is the world’s first real-time soil ana...
# 298  What gets you out of bed in the morning and ke...
# 299  We are hiring\n\nAt PERMACON you will find the...
# 300  Department: Offprice Data Science\n\nReports t...
# 301  Executive Principal Data Engineer - Digital Fo...
#
#                                                    url  \
# 0    https://www.glassdoor.de/job-listing/data-scie...
# 2    https://www.glassdoor.de/job-listing/data-arch...
# 3    https://www.glassdoor.de/job-listing/data-scie...
# 4    https://www.glassdoor.de/job-listing/data-scie...
# 5    https://www.glassdoor.de/job-listing/data-scie...
# ..                                                 ...
# 297  https://www.glassdoor.de/job-listing/senior-da...
# 298  https://www.glassdoor.de/job-listing/data-arch...
# 299  https://www.glassdoor.de/job-listing/senior-sc...
# 300  https://www.glassdoor.de/job-listing/software-...
# 301  https://www.glassdoor.de/job-listing/executive...
#
#                                                  clean language
# 0    [job, description, tg, detail, role, fit, team...       en
# 2    [get, bed, morning, keep, motivated, throughou...       en
# 3    [welcome, centogene, centogene, gmbh, centogen...       en
# 4    [marley, spoon, new, way, cook, bring, delight...       en
# 5    [responsibility, include, limited, following, ...       en
# ..                                                 ...      ...
# 297  [stenon, world, ’, first, realtime, soil, anal...       en
# 298  [get, bed, morning, keep, motivated, throughou...       en
# 299  [hiring, permacon, find, seriousness, security...       en
# 300  [department, offprice, data, science, report, ...       en
# 301  [executive, principal, data, engineer, digital...       en
#
# [216 rows x 6 columns]
