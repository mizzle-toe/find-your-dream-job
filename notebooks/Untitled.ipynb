# %%
# %load_ext autoreload
# %autoreload 2

# %%
from fydjob.NLPFrame import NLPFrame
df = NLPFrame().df

df.head(5)
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     /Users/alexanderherdt/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     /Users/alexanderherdt/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /Users/alexanderherdt/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# Loaded from /Users/alexanderherdt/code/mizzle-toe/find-your-dream-job/fydjob/output/nlp_frame.joblib
# [nltk_data] Downloading package punkt to
# [nltk_data]     /Users/alexanderherdt/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     /Users/alexanderherdt/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /Users/alexanderherdt/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# Loaded from /Users/alexanderherdt/code/mizzle-toe/find-your-dream-job/fydjob/output/nlp_frame.joblib
#    job_id                                   job_title  \
# 0       1  Data Scientist / Matching Engineer (m/w/d)
# 1       2    Senior Software Engineer - Data Platform
# 2       3                Senior Data Engineer (m/w/t)
# 3       4                       Data Engineer (w/m/d)
# 4       5                               Data Engineer
#
#                                             job_text          company  \
# 0  You are responsible for improvement of Taledo’...           Taledo
# 1  We are looking for a Senior Software Engineer ...       Zalando SE
# 2  As a member of the Data Engineering Team, you ...     Quandoo GmbH
# 3  We are digitty.io – an international start-up ...       digitty.io
# 4  We activate data for our clients by using stat...  Gemma Analytics
#
#   location                                           job_info job_link  \
# 0   Berlin  Data Scientist / Matching Engineer (m/w/d)\nTa...     NULL
# 1   Berlin  Senior Software Engineer - Data Platform\nZala...     NULL
# 2   Berlin  Senior Data Engineer (m/w/t)\nQuandoo GmbH17 B...     NULL
# 3   Berlin         Data Engineer (w/m/d)\ndigitty.io - Berlin     NULL
# 4   Berlin            Data Engineer\nGemma Analytics - Berlin     NULL
#
#       query_text       source tag_language reviews  \
# 0  data engineer  scrape_json           en    NULL
# 1  data engineer  scrape_json           en    NULL
# 2  data engineer  scrape_json           en    NULL
# 3  data engineer  scrape_json           en    NULL
# 4  data engineer  scrape_json           en    NULL
#
#                                   job_info_tokenized  \
# 0  [data, scientist, matching, engineer, mwd, tal...
# 1  [senior, software, engineer, data, platform, z...
# 2  [senior, data, engineer, mwt, quandoo, gmbh, b...
# 3           [data, engineer, wmd, digittyio, berlin]
# 4         [data, engineer, gemma, analytics, berlin]
#
#                                   job_text_tokenized  \
# 0  [you, are, responsible, for, improvement, of, ...
# 1  [we, are, looking, for, a, senior, software, e...
# 2  [as, a, member, of, the, data, engineering, te...
# 3  [we, are, digittyio, an, international, startu...
# 4  [we, activate, data, for, our, clients, by, us...
#
#                         job_text_tokenized_titlecase  \
# 0  [Data, Scientist, Matching, Engineer, mwd, Tal...
# 1  [Senior, Software, Engineer, Data, Platform, Z...
# 2  [Senior, Data, Engineer, mwt, Quandoo, GmbH, B...
# 3           [Data, Engineer, wmd, digittyio, Berlin]
# 4         [Data, Engineer, Gemma, Analytics, Berlin]
#
#                             job_title_tokenized  \
# 0    [data, scientist, matching, engineer, mwd]
# 1  [senior, software, engineer, data, platform]
# 2                 [senior, data, engineer, mwt]
# 3                         [data, engineer, wmd]
# 4                              [data, engineer]
#
#                         job_text_tokenized_processed
# 0  [responsible, improvement, taledos, search, ma...
# 1  [looking, senior, software, engineer, extensiv...
# 2  [member, data, engineering, team, responsible,...
# 3  [digittyio, international, startup, headquarte...
# 4  [activate, data, client, using, stateoftheart,...

# %%
from fydjob.Word2VecPipeline import WordPipeline
from fydjob.utils import category_tagger

pipeline = WordPipeline()

# %%
pipeline.process_text_field(df)
# Out:
# [['responsible',
#   'improvement',
#   'taledo',
#   '’',
#   'search',
#   'matching',
#   'engine',
#   'candidates',
#   'jobs',
#   'business',
#   'drivers',
#   'data',
#   'science'],
#  ['develop',
#   'compare',
#   'different',
#   'algorithmic',
#   'approaches',
#   'andor',
#   'ml',
#   'models'],
#  ['monitor', 'production', 'performance', 'measure', 'success', 'work'],
#  ['update', 'outdated', 'models'],
#  ['research',
#   'discuss',
#   'algorithmical',
#   'well',
#   'model',
#   'improvements',
#   'regularly'],
#  ['knowledgeable',
#   'developed',
#   'ai',
#   'community',
#   'propose',
#   '’',
#   'applicable',
#   'taledo'],
#  ['expect', 'curious', 'nature'],
#  ['like',
#   'solve',
#   'challenging',
#   'problems',
#   'proficient',
#   'python',
#   'worked',
#   'relevant',
#   'libraries',
#   'know',
#   'use',
#   'data',
#   'handling',
#   'numpy',
#   'pandas',
#   'dask',
#   'psycopg',
#   'mldl',
#   'scikitlearn',
#   'xgboost',
#   'keras',
#   'pytorch',
#   'spacy',
#   'visualization',
#   'seaborn',
#   'matplotlib',
#   'experience',
#   'evaluating',
#   'different',
#   'approaches',
#   'choosing',
#   'appropriate',
#   'metric',
#   'worked',
#   'search',
#   'matching',
#   'nlp',
#   'using',
#   'various',
#   'approaches',
#   'mldl',
#   'besides',
#   'success',
#   'stories',
#   'also',
#   'know',
#   '’',
#   'worked',
#   'experience',
#   'elasticsearch',
#   'plus',
#   'translate',
#   'user',
#   'talk',
#   'observed',
#   'behaviour',
#   'algorithmic',
#   'approach'],
#  ['switch',
#   'fluently',
#   'levels',
#   'details',
#   'big',
#   'picture',
#   'algorithmical',
#   'details',
#   'creative',
#   'generate',
#   'ideas'],
#  ['revolutionizing',
#   'industry',
#   'wed',
#   'love',
#   'see',
#   'exceptional',
#   'ideas',
#   '’',
#   'handson',
#   'like',
#   'get',
#   'things',
#   'done'],
#  ['work',
#   'autonomously',
#   'proactive',
#   'speak',
#   'fluent',
#   'english',
#   'berlin',
#   'plus',
#   'offer',
#   'work',
#   'challenging',
#   'domain',
#   'matching',
#   'candidates',
#   'jobs',
#   'work',
#   'mission',
#   'real',
#   'impact',
#   'people',
#   'direct',
#   'impact',
#   'candidates',
#   'career',
#   'development',
#   'work',
#   'decides',
#   'put',
#   'cv'],
#  ['furthermore', 'support', 'companies', 'important', 'asset', 'people'],
#  ['responsibility',
#   'start',
#   'flat',
#   'hierarchy',
#   'environment',
#   '‘',
#   'doer',
#   'maker',
#   '’',
#   'mindset'],
#  ['contribute',
#   'directly',
#   'taledos',
#   'growth',
#   'story',
#   'leave',
#   'footprint',
#   'trustful',
#   'environment',
#   'open',
#   'conversations',
#   'transparency',
#   'blame',
#   'shame',
#   'culture',
#   'team',
#   'personal',
#   'development',
#   'plan',
#   'discussed',
#   'manager',
#   'individually',
#   'frequent',
#   'feedback',
#   'manager',
#   'knowledge',
#   'sharing',
#   'constant',
#   'learning',
#   'e.g'],
#  ['educational',
#   'budget',
#   'hackathons',
#   'flexible',
#   'working',
#   'hours',
#   'home',
#   'office'],
#  ['maybe',
#   'attractive',
#   'corona',
#   'office',
#   'additional',
#   'vacation',
#   'days',
#   'based',
#   'tenure',
#   'seniority',
#   'international',
#   'team',
#   'team',
#   'events',
#   'socializing',
#   'activities',
#   'taledo',
#   'allinone',
#   'suite',
#   'talent',
#   'acquisition',
#   'relations'],
#  ['offer',
#   'talent',
#   'marketing',
#   'recruiting',
#   'service',
#   'candidate',
#   'management',
#   'single',
#   'platform'],
#  ['part',
#   'solution',
#   'matching',
#   'top',
#   'candidates',
#   'best',
#   'companies',
#   'germany',
#   'received',
#   'funding',
#   'eu'],
#  ['besides',
#   'technology',
#   'team',
#   'recruiting',
#   'experts',
#   '’',
#   'lose',
#   'human',
#   'touch',
#   'oftentimes',
#   'missing',
#   'recruiting',
#   'solutions'],
#  ['heute', 'weiter', 'zur', 'bewerbung', 'diesen', 'job', 'melden'],
#  ['looking',
#   'senior',
#   'software',
#   'engineer',
#   'extensive',
#   'experience',
#   'creating',
#   'jvm',
#   'rest',
#   'api',
#   'interested',
#   'learning',
#   'manage',
#   'cloud',
#   'data',
#   'platform',
#   'online',
#   'fashion',
#   'retailer'],
#  ['use',
#   'expertise',
#   'create',
#   'automation',
#   'services',
#   'needed',
#   'achieve',
#   'compliance',
#   'operational',
#   'excellence',
#   'cost',
#   'efficiency',
#   'data',
#   'practitioner',
#   'productivity'],
#  ['expertise',
#   'needed',
#   'part',
#   'data',
#   'infrastructure',
#   'platform',
#   'team',
#   'team',
#   'code',
#   'decide',
#   'technologies',
#   'tools',
#   'deliver',
#   'well',
#   'operate',
#   'largescale',
#   'applications',
#   'services',
#   'paassaas',
#   'cloud',
#   'aws',
#   'google',
#   'cloud',
#   'consult',
#   'help',
#   'teams',
#   'develop',
#   'implement',
#   'maintain',
#   'sustainable',
#   'highperformance',
#   'growthready',
#   'dataprocessing',
#   'data',
#   'integration',
#   'systems',
#   'adding',
#   'value',
#   'leveraging',
#   'setting',
#   'new',
#   'trends',
#   'software',
#   'engineering',
#   'design',
#   'architecture',
#   'implementation',
#   'highly',
#   'used',
#   'data',
#   'services',
#   'support',
#   'strategy',
#   'come',
#   'innovating',
#   'ideas',
#   'build',
#   'world',
#   'class',
#   'data',
#   'integration',
#   'systems',
#   'one',
#   'step',
#   'ahead',
#   'industry',
#   '’',
#   'looking',
#   'expert',
#   'javascala',
#   'experienced',
#   'python',
#   'expert',
#   'spring',
#   'play',
#   'equivalent',
#   'ability',
#   'interest',
#   'translating',
#   'business',
#   'requirements',
#   'technological',
#   'visions',
#   'reimagining',
#   'dataprocessing',
#   'technologies',
#   'ambitious',
#   'optimizing',
#   'researching',
#   'distributed',
#   'systems',
#   'like',
#   'presto',
#   'hive',
#   'spark',
#   'serverless',
#   'technology',
#   'like',
#   'aws',
#   'lambda',
#   'work',
#   'scale',
#   'nice',
#   'data',
#   'engineering',
#   'experience',
#   'spark',
#   'cloud',
#   'engineering',
#   'experience',
#   'aws',
#   'google',
#   'aws',
#   'serverless',
#   'experience',
#   'experience',
#   'operating',
#   'scale',
#   'bigquery',
#   'presto',
#   'exasol'],
#  ['perks',
#   'work',
#   'culture',
#   'trust',
#   'empowerment',
#   'constructive',
#   'feedback',
#   'open',
#   'source',
#   'commitment',
#   'meetups',
#   'game',
#   'nights',
#   'internal',
#   'technical',
#   'fun',
#   'guilds',
#   'knowledge',
#   'sharing',
#   'tech',
#   'talks',
#   'internal',
#   'tech',
#   'academy',
#   'blogs',
#   'product',
#   'demos',
#   'parties',
#   'events',
#   'competitive',
#   'salary',
#   'employee',
#   'share',
#   'shop',
#   'zalando',
#   'shopping',
#   'discount',
#   'discounts',
#   'external',
#   'partners',
#   'centrally',
#   'located',
#   'offices',
#   'public',
#   'transport',
#   'discounts',
#   'municipality',
#   'services',
#   'great',
#   'equipment',
#   'flexible',
#   'working',
#   'times',
#   'additional',
#   'holidays',
#   'volunteering',
#   'time',
#   'free',
#   'beverages',
#   'fruits',
#   'diverse',
#   'sports',
#   'health',
#   'offerings',
#   'extensive',
#   'onboarding',
#   'mentoring',
#   'personal',
#   'development',
#   'opportunities',
#   'international',
#   'team',
#   'experts',
#   'relocation',
#   'assistance',
#   'internationals',
#   'pme',
#   'family',
#   'service',
#   'parent',
#   'child',
#   'rooms',
#   'available',
#   'select',
#   'locations',
#   'celebrate',
#   'diversity',
#   'committed',
#   'building',
#   'teams',
#   'represent',
#   'variety',
#   'backgrounds',
#   'perspectives',
#   'skills'],
#  ['employment',
#   'decided',
#   'basis',
#   'qualifications',
#   'merit',
#   'business',
#   'need'],
#  ['zalando', 'heute', 'weiter', 'zur', 'bewerbung', 'diesen', 'job', 'melden'],
#  ['member',
#   'data',
#   'engineering',
#   'team',
#   'responsible',
#   'development',
#   'upkeep',
#   'data',
#   'ingestions',
#   'processing',
#   'pipelines',
#   'data',
#   'used',
#   'analysts',
#   'teams',
#   'monitoring',
#   'maintenance',
#   'data',
#   'quality',
#   'reliability',
#   'working',
#   'business',
#   'analysts',
#   'bring',
#   'results',
#   'work',
#   'management',
#   'support',
#   'analysts',
#   'technical',
#   'expertise',
#   'tooling',
#   'translating',
#   'requirements',
#   'reporting',
#   'users',
#   'platform',
#   'backend',
#   'developers',
#   'qualifications',
#   'sound',
#   'programming',
#   'skills',
#   'preferably',
#   'preferably',
#   'python',
#   'scala',
#   'high',
#   'proficiency',
#   'sql',
#   'understanding',
#   'etl',
#   'concepts',
#   'tools',
#   'technologies',
#   'e.g'],
#  ['dataflow',
#   'airflow',
#   'understanding',
#   'dwh',
#   'concepts',
#   'architecture',
#   'technologies',
#   'e.g'],
#  ['redshift',
#   'bigquery',
#   'past',
#   'experience',
#   'cloud',
#   'technologies',
#   'preferably',
#   'gcp',
#   'experience',
#   'docker',
#   'kubernetes',
#   'enthusiasm',
#   'willingness',
#   'learn',
#   'keep',
#   'speed',
#   'modern',
#   '“',
#   'big',
#   'data',
#   '”',
#   'tech',
#   'analytical',
#   'mind',
#   'drive',
#   'back',
#   'decisions',
#   'data',
#   'professional',
#   'level',
#   'english',
#   'additional',
#   'languages',
#   'plus',
#   'nice',
#   'understanding',
#   'web',
#   'mobile',
#   'tracking',
#   'technologies',
#   'ga',
#   'gtm',
#   'adjust',
#   'leanplum',
#   'understanding',
#   'ml',
#   'methods',
#   'tools',
#   'model',
#   'creation',
#   'scikitlearn',
#   'experience',
#   'event',
#   'driven',
#   'data',
#   'processing',
#   'kafka',
#   'kinesis',
#   'experience',
#   'aws',
#   'stack',
#   'ec',
#   'dms',
#   'athena',
#   '...',
#   'experience',
#   'bigdata',
#   'tools',
#   'e.g'],
#  ['spark',
#   'hadoop',
#   'additional',
#   'information',
#   'offer',
#   'attractive',
#   'perks',
#   '–',
#   'access',
#   'quandoo',
#   '’',
#   'pension',
#   'scheme',
#   'well',
#   'various',
#   'fitness',
#   'lifestyle',
#   'benefits',
#   'modern',
#   'equipment',
#   '–',
#   'stateoftheart',
#   'laptop',
#   'tools',
#   'needed',
#   'optimal',
#   'work',
#   'results',
#   'fun',
#   'working',
#   'environment',
#   '–',
#   'opportunity',
#   'collaborate',
#   'highly',
#   'motivated',
#   'colleagues',
#   'attend',
#   'company',
#   'parties',
#   'weekly',
#   'qweekend',
#   'quandoo',
#   '’',
#   'global',
#   'summit',
#   'workhome',
#   'balance',
#   '–',
#   'flexible',
#   'working',
#   'hours',
#   'home',
#   'office',
#   'possibilities',
#   'days',
#   'vacation',
#   'high',
#   'level',
#   'responsibility',
#   '–',
#   'chance',
#   'hit',
#   'ground',
#   'running',
#   'day',
#   'one',
#   'shape',
#   'career',
#   'path',
#   'want',
#   'part',
#   'quandoo',
#   '’',
#   'future',
#   'apply',
#   'heute',
#   'weiter',
#   'zur',
#   'bewerbung',
#   'diesen',
#   'job',
#   'melden'],
#  ['digitty.io',
#   '–',
#   'international',
#   'startup',
#   'headquarter',
#   'berlin',
#   'prenzlauer',
#   'berg'],
#  ['saas',
#   'product',
#   'fundamentally',
#   'change',
#   'projects',
#   'planned',
#   'implemented',
#   'delivered'],
#  ['use', 'latest', 'technologies', 'approaches', 'product'],
#  ['interdisciplinary',
#   'diverse',
#   'experienced',
#   'team',
#   'consisting',
#   'globally',
#   'recognized',
#   'specialists',
#   'advisors',
#   'benefit',
#   'development',
#   'programs',
#   'attractive',
#   'salary',
#   'open',
#   'error',
#   'culture',
#   'freedom',
#   'create',
#   'digitty.io',
#   'product',
#   'us'],
#  ['role',
#   'digitty.io',
#   'support',
#   'organisation',
#   'driving',
#   'user',
#   'acquisition',
#   'integration',
#   'data',
#   'source',
#   'effectively',
#   'leveraging',
#   'data',
#   'owning',
#   'various',
#   'parts',
#   'product',
#   'analytics',
#   'driving',
#   'initiatives',
#   'help',
#   'digitty.io',
#   'grow',
#   'involved',
#   'stages',
#   'analysis',
#   'including',
#   'cleaning',
#   'raw',
#   'data',
#   'defining',
#   'key',
#   'metrics',
#   'setting',
#   'transformations',
#   'creating',
#   'visualisations',
#   'presenting',
#   'findings',
#   'ensuring',
#   'digitty.io',
#   'highquality',
#   'data',
#   'work',
#   'work',
#   'latest',
#   'technologies',
#   'tools',
#   'software',
#   'bring',
#   'along',
#   'experience',
#   'automation',
#   'maintenance',
#   'operation',
#   'saas',
#   'environments',
#   'gcp',
#   'aws',
#   'ms',
#   'azure',
#   'good',
#   'knowledge',
#   'python',
#   'nodejs',
#   'well',
#   'sql',
#   'nosql',
#   'experience',
#   'bi',
#   'frontends',
#   'e.g'],
#  ['qlik',
#   'datadog',
#   'tableau',
#   'power',
#   'bi',
#   'microstrategy',
#   'data',
#   'warehouse',
#   'systems',
#   'e.g'],
#  ['snowflake',
#   'redshift',
#   'bigquery',
#   'teradata',
#   'confident',
#   'take',
#   'initiative',
#   'present',
#   'new',
#   'ideas',
#   'peers',
#   'business',
#   'oriented',
#   'mindset',
#   'positive',
#   'attitude',
#   'ability',
#   'work',
#   'multiple',
#   'projects',
#   'include',
#   'effective',
#   'prioritisation',
#   'timely',
#   'completion',
#   'awaits',
#   'us',
#   'working',
#   'alongside',
#   'worldwide',
#   'respected',
#   'experts',
#   'advisors',
#   'field',
#   'ai',
#   'data',
#   'science'],
#  ['working',
#   'scientific',
#   'council',
#   'consisting',
#   'renowned',
#   'scientists',
#   'fields',
#   'business',
#   'behavioural',
#   'psychology',
#   'language',
#   'office',
#   'broken',
#   'english',
#   'topnotch',
#   'hardware',
#   'equipment',
#   'flexible',
#   'working',
#   'hours',
#   'home',
#   'office',
#   'option',
#   'flexible',
#   'career',
#   'development',
#   'path',
#   'within',
#   'international',
#   'diverse',
#   'team',
#   'working',
#   'first',
#   'mover',
#   'startup',
#   'potential',
#   'become',
#   'international',
#   'company',
#   'within',
#   'next',
#   'years',
#   'competitive',
#   'salary',
#   'employee',
#   'shares',
#   'chance',
#   'part',
#   'fast',
#   'growing',
#   'international',
#   'tech',
#   'community',
#   'members',
#   'digitty.io',
#   'choice',
#   'diversity',
#   'makes',
#   'us',
#   'proud',
#   'company'],
#  ['addition',
#   'flexible',
#   'working',
#   'time',
#   'agile',
#   'working',
#   'methods',
#   'integrated',
#   'projects',
#   'expect',
#   'comprehensive',
#   'range',
#   'training',
#   'opportunities',
#   'managers',
#   'eye',
#   'level'],
#  ['ready',
#   'join',
#   'us',
#   'apply',
#   'via',
#   'jobsdigitty.io',
#   'cv',
#   'without',
#   'photo',
#   'cover',
#   'letter'],
#  ['equalopportunity', 'employer', 'value', 'diversity'],
#  ['consider',
#   'applications',
#   'equally',
#   'regardless',
#   'race',
#   'color',
#   'ancestry',
#   'religion',
#   'sex',
#   'national',
#   'origin',
#   'sexual',
#   'orientation',
#   'age',
#   'citizenship',
#   'marital',
#   'status',
#   'disability',
#   'gender',
#   'identity'],
#  ['furthermore',
#   'strongly',
#   'encourage',
#   'individuals',
#   'groups',
#   'traditionally',
#   'underrepresented',
#   'tech',
#   'apply'],
#  ['media.net',
#   'berlinbrandenburg',
#   'vor',
#   'tag',
#   'weiter',
#   'zur',
#   'bewerbung',
#   'diesen',
#   'job',
#   'melden'],
#  ['activate', 'data', 'clients', 'using', 'stateoftheart', 'technology'],
#  ['help', 'clients', 'make', 'better', 'decisions'],
#  ['empower', 'customers', 'make', 'use', 'data'],
#  ['clients',
#   'range',
#   'series',
#   'ventures',
#   'smes',
#   'employees',
#   'per',
#   'client'],
#  ['honest', 'pleasant', 'fun', 'work', 'environment'],
#  ['please',
#   'make',
#   'reference',
#   'calls',
#   'us',
#   'validation',
#   'tasks',
#   'job',
#   'gemma',
#   'analytics',
#   'datadriven',
#   'helps',
#   'clients',
#   'become',
#   'datadriven'],
#  ['first',
#   'pure',
#   'data',
#   'engineer',
#   'team',
#   'play',
#   'crucial',
#   'role',
#   'developing',
#   'opensource',
#   'python',
#   'library',
#   'ewah',
#   'tool',
#   'use',
#   'internally',
#   'clients',
#   'tool',
#   'data',
#   'engineers',
#   'companies',
#   'love',
#   'use',
#   'data',
#   'stack'],
#  ['challenges',
#   'opensource',
#   'library',
#   'solves',
#   'following',
#   'data',
#   'transfer',
#   'raw',
#   'data',
#   'sources',
#   'data',
#   'warehouses',
#   'enabling',
#   'analytics',
#   'engineers',
#   'set',
#   'maintain',
#   'stateoftheart',
#   'data',
#   'infrastructures',
#   'using',
#   'opensource',
#   'software',
#   'components',
#   'gdpr',
#   'compliance',
#   'data',
#   'leave',
#   'customer',
#   '’',
#   'environment',
#   'save',
#   'time',
#   'data',
#   'engineers',
#   'analytics',
#   'engineers',
#   'abstracting',
#   'away',
#   'data',
#   'engineering',
#   'issues',
#   'besides',
#   'developing',
#   'opensource',
#   'application',
#   'challenges',
#   'imposed',
#   'existing',
#   'new',
#   'clients',
#   'circle',
#   'around',
#   'connection',
#   'new',
#   'data',
#   'sources',
#   'new',
#   'target',
#   'databases',
#   'custom',
#   'requests',
#   'circling',
#   'around',
#   'setting',
#   'maintaining',
#   'effective',
#   'efficient',
#   'data',
#   'infrastructure',
#   'across',
#   'entire',
#   'client',
#   'portfolio'],
#  ['looking',
#   'person',
#   'loves',
#   'abstractions',
#   'understands',
#   'apply',
#   'abstractions',
#   'make',
#   'everyone',
#   '’',
#   'life',
#   'easier'],
#  ['technologies',
#   '’',
#   'use',
#   'working',
#   'multiple',
#   'clients',
#   'touch',
#   'many',
#   'technologies',
#   'truly',
#   'exciting'],
#  ['aim',
#   'use',
#   'stateoftheart',
#   'technologies',
#   'fully',
#   'pragmatic',
#   'crack',
#   'walnut',
#   'sledgehammer'],
#  ['follow',
#   'elt',
#   'philosophy',
#   'divide',
#   'tasks',
#   'data',
#   'engineering',
#   'analytics',
#   'engineering',
#   'accordingly'],
#  ['following',
#   'technologies',
#   'constitute',
#   'preferred',
#   'data',
#   'tech',
#   'stack',
#   'data',
#   'loading',
#   'clients',
#   'use',
#   'opensource',
#   'python',
#   'library',
#   'ewah',
#   'apache',
#   'airflow',
#   'simple',
#   'requests',
#   'work',
#   'fivetran',
#   'stitch',
#   'data',
#   'warehousing',
#   'smaller',
#   'data',
#   'loads',
#   'mostly',
#   'use',
#   'postgresql',
#   'databases',
#   'larger',
#   'datasets',
#   'work',
#   'snowflake',
#   'bigquery',
#   'data',
#   'transformation',
#   'love',
#   'work',
#   'data',
#   'build',
#   'tool',
#   'dbt',
#   'data',
#   'visualization',
#   'smaller',
#   'businesses',
#   'fte',
#   'mostly',
#   'recommend',
#   'metabase',
#   'powerful',
#   'opensource',
#   'reporting',
#   'tool',
#   'specified',
#   'needs',
#   'centralized',
#   'bi',
#   'recommend',
#   'powerbi',
#   'tableau',
#   'decentralized',
#   'selfservice',
#   'bi',
#   'users',
#   'recommend',
#   'looker',
#   'requirements',
#   'believe',
#   'good',
#   'mixture',
#   'experience',
#   'upside',
#   'team'],
#  ['looking', 'types', 'people', 'equally'],
#  ['besides',
#   'looking',
#   'following',
#   'extensive',
#   'experience',
#   'using',
#   'python',
#   'solve',
#   'data',
#   'engineering',
#   'challenges',
#   'production',
#   'fluency',
#   'english',
#   'optional',
#   'experience',
#   'creating',
#   'shipping',
#   'maintaining',
#   'highquality',
#   'open',
#   'source',
#   'applications',
#   'optional',
#   'experience',
#   'sql',
#   'relational',
#   'databases',
#   'benefits',
#   'located',
#   'berlin',
#   'close',
#   'nordbahnhof',
#   'currently',
#   'colleagues',
#   'grow',
#   'colleagues',
#   'coming',
#   'months'],
#  ['perks',
#   'include',
#   'remotefriendly',
#   'uncertain',
#   'times',
#   'honest',
#   'inclusive',
#   'work',
#   'environment',
#   'want',
#   'nurture',
#   'environment',
#   'equip',
#   'powerful',
#   'thinkpads',
#   'multiple',
#   'screens',
#   'make',
#   'sure',
#   'tools',
#   'need',
#   'surround',
#   'likeminded',
#   'people',
#   'love',
#   'solve',
#   'data',
#   'riddles',
#   'believe',
#   'efficient',
#   'working',
#   'hours',
#   'rather',
#   'long',
#   'working',
#   'hours',
#   'focus',
#   'output',
#   'rather',
#   'input',
#   'learn',
#   'share',
#   'meetups',
#   'lunchlearn',
#   'sessions',
#   'open',
#   'initiatives',
#   'pay',
#   'marketfriendly',
#   'salary',
#   'additionally',
#   'distribute',
#   'least',
#   'profits',
#   'employees',
#   'great',
#   'yearly',
#   'offsite',
#   'event',
#   'brings',
#   'us',
#   'together',
#   'full',
#   'week',
#   'enjoying',
#   'good',
#   'food',
#   'good',
#   'time',
#   'course',
#   'solving',
#   'complex',
#   'datarelated',
#   'challenges',
#   '’',
#   'get'],
#  ['cv', 'screening'],
#  ['phonecoffeetea', 'conversation'],
#  ['interviews', 'future', 'colleagues'],
#  ['offer',
#   'hired',
#   'looking',
#   'forward',
#   'application',
#   'vor',
#   'tag',
#   'weiter',
#   'zur',
#   'bewerbung',
#   'diesen',
#   'job',
#   'melden'],
#  ['td',
#   'reply',
#   'innovation',
#   'marketing',
#   'consultancy',
#   'part',
#   'reply',
#   'group'],
#  ['take',
#   'data',
#   'driven',
#   'executionoriented',
#   'approach',
#   'drive',
#   'organizational',
#   'change',
#   'meaningful',
#   'insights'],
#  ['berlin',
#   'munich',
#   'beijing',
#   'offices',
#   'around',
#   'thinkers',
#   'developers',
#   'analysts',
#   'designers',
#   'consultants',
#   'visualizers',
#   'futurologists',
#   'data',
#   'scientists',
#   'organizers'],
#  ['working',
#   'international',
#   'data',
#   'science',
#   'projects',
#   'clients',
#   'audi',
#   'adidas',
#   'cocacola',
#   'miele',
#   'telefonica',
#   'bmw'],
#  ['team',
#   'looking',
#   'junior',
#   'consultant',
#   'field',
#   'datadriven',
#   'trend',
#   'marketing',
#   'research'],
#  ['believe',
#   'data',
#   'power',
#   'drive',
#   'inspiration',
#   'make',
#   'better',
#   'decisions',
#   'continuously',
#   'build',
#   'develop',
#   'set',
#   'tools',
#   'analytical',
#   'approaches',
#   'trend',
#   'research',
#   'solution',
#   'sonar',
#   'initiated',
#   'together',
#   'german',
#   'research',
#   'center',
#   'artificial',
#   'intelligence',
#   'dfki'],
#  ['information',
#   'look',
#   'httpstrendsonar.com',
#   'please',
#   'indicate',
#   'preferred',
#   'location'],
#  ['’',
#   'passion',
#   'research',
#   'innovation',
#   'understanding',
#   'consumer',
#   'behaviour',
#   'possess',
#   'innate',
#   'curiosity',
#   'keen',
#   'eye',
#   'interesting',
#   'trends',
#   'future',
#   'developments',
#   'keen',
#   'master',
#   'data',
#   'analytics',
#   'tools',
#   'smarter',
#   'informed',
#   'decision',
#   'making',
#   'take',
#   'chance',
#   'join',
#   'team',
#   'datadriven',
#   'trend',
#   'marketing',
#   'consultants'],
#  ['whether',
#   'performing',
#   'market',
#   'consumer',
#   'technology',
#   'research',
#   'identifying',
#   'latest',
#   'trends',
#   'preparing',
#   'findings',
#   '–',
#   'fully',
#   'involved',
#   'trend',
#   'marketing',
#   'research',
#   'process',
#   'using',
#   'wide',
#   'range',
#   'stateoftheart',
#   'analytical',
#   'techniques',
#   'tools'],
#  ['member',
#   'data',
#   'intelligence',
#   'team',
#   'ask',
#   'answer',
#   'shrewd',
#   'questions',
#   'face',
#   'critical',
#   'analysis',
#   'strategic',
#   'foresight',
#   'turn',
#   'data',
#   'insights'],
#  ['support',
#   'clients',
#   'transform',
#   'brands',
#   'future',
#   'strategies',
#   '–',
#   'based',
#   'smart',
#   'data'],
#  ['tasks',
#   'include',
#   'valuable',
#   'part',
#   'team',
#   'consisting',
#   'consultants',
#   'data',
#   'scientists',
#   'innovators',
#   'design',
#   'thinkers',
#   'trend',
#   'marketing',
#   'researchers'],
#  ['work',
#   'various',
#   'digital',
#   'data',
#   'sources',
#   'trend',
#   'sonar',
#   'tool',
#   'google',
#   'search',
#   'social',
#   'listening',
#   'etc'],
#  ['generate', 'trend', 'market', 'consumer', 'insights'],
#  ['systematically',
#   'continuous',
#   'datadriven',
#   'exploration',
#   'identification',
#   'analysis',
#   'market',
#   'technology',
#   'consumer',
#   'trends',
#   'trend',
#   'topicspecific',
#   'data',
#   'mining',
#   'integrating',
#   'unifying',
#   'data',
#   'various',
#   'sources',
#   'trend',
#   'market',
#   'research',
#   'continuous',
#   'trend',
#   'monitoring',
#   'qualitative',
#   'quantitative',
#   'deep',
#   'dive',
#   'analysis',
#   'consumer',
#   'trend',
#   'market',
#   'data',
#   'derive',
#   'meaningful',
#   'insights',
#   'market',
#   'dynamics',
#   'future',
#   'trends',
#   'create',
#   'insightful',
#   'reports',
#   'content',
#   'client',
#   'presentations',
#   'collaborate',
#   'closely',
#   'wide',
#   'range',
#   'international',
#   'clients',
#   'understanding',
#   'business',
#   'needs',
#   'challenges',
#   'support',
#   'conduction',
#   'ideation',
#   'workshops',
#   'develop',
#   'new',
#   'trendinspired',
#   'product',
#   'service',
#   'ideas',
#   'based',
#   'research',
#   'results',
#   '’',
#   'match',
#   'if…',
#   '…',
#   'hold',
#   'advanced',
#   'degree',
#   'future',
#   'studies',
#   'economics',
#   'behavioral',
#   'social',
#   'science',
#   'psychology',
#   'industrial',
#   'engineering',
#   'statistics',
#   'related',
#   'field',
#   'ideally',
#   'focus',
#   'innovation',
#   'management',
#   'marketingfuturetrend',
#   'research',
#   '…',
#   'first',
#   'assignment'],
#  ['least',
#   'years',
#   'relevant',
#   'experience',
#   'marketing',
#   'consumer',
#   'trend',
#   'research',
#   'data',
#   'mining',
#   'analytics',
#   'data',
#   'insights',
#   'digital',
#   'agency',
#   'consultancy',
#   '…',
#   'good',
#   'understanding',
#   'business',
#   'analysis',
#   'techniques',
#   'keen',
#   'perception',
#   'strong',
#   'sense',
#   'responsibility',
#   '…',
#   'possess',
#   'high',
#   'affinity',
#   'future',
#   'trends',
#   'like',
#   'date',
#   'latest',
#   'technological',
#   'developments',
#   '…',
#   'bring',
#   'along',
#   'passion',
#   'things',
#   'digital',
#   '…',
#   'analytical',
#   'creative',
#   'thinking',
#   'underlined',
#   'insatiable',
#   'curiosity',
#   '…',
#   'analyze',
#   'prepare',
#   'present',
#   'complex',
#   'concepts',
#   'clear',
#   'meaningful',
#   'manner',
#   '…',
#   'fluent',
#   'english',
#   'german',
#   '…',
#   'open',
#   'minded',
#   'inspired',
#   'individual',
#   'team',
#   'player',
#   '...',
#   'knowledge',
#   'tools',
#   'field',
#   'social',
#   'listening',
#   'e.g'],
#  ['brandwatch',
#   'talkwalker',
#   'digital',
#   'trend',
#   'foresighting',
#   'consumer',
#   'interest',
#   'analytics',
#   'e.g'],
#  ['google', 'trendsadwords', 'plus'],
#  ['’',
#   'collaborate',
#   'experienced',
#   'enthusiastic',
#   'team',
#   'lot',
#   'ideas',
#   'great',
#   'challenging',
#   'clients',
#   'highly',
#   'diverse',
#   'projects'],
#  ['berlin', 'mitte', 'hackescher', 'markt', 'feet'],
#  ['part', 'awesome', 'work', 'environment', 'team', 'warmly', 'welcomes'],
#  ['tailor', 'package', '’', 'right'],
#  ['application',
#   'want',
#   'hire',
#   'ok',
#   'totally',
#   'honest',
#   'qualify',
#   'statement',
#   '’',
#   'talented',
#   'hardworking',
#   'smart',
#   'brave',
#   'innovative',
#   'humble',
#   'confident',
#   'nice',
#   'love',
#   'working',
#   'data',
#   'driven',
#   'industry',
#   'want',
#   'hire'],
#  ['learn',
#   'approach',
#   'datadriven',
#   'innovation',
#   'read',
#   'steffen',
#   '’',
#   'blog',
#   'post',
#   'innovation',
#   'understanding'],
#  ['learn',
#   'approach',
#   'smart',
#   'data',
#   'read',
#   'blog',
#   'post',
#   'big',
#   'smart',
#   'data',
#   '–',
#   'rough',
#   'guide',
#   'datadriven',
#   'marketing'],
#  ['interested', 'please', 'submit', 'resume', 'reply', 'recruiter'],
#  ['vor', 'tag', 'weiter', 'zur', 'bewerbung', 'diesen', 'job', 'melden'],
#  ['spirit',
#   'startup',
#   'one',
#   'germanys',
#   'largest',
#   'familyrun',
#   'businesses',
#   'contradiction',
#   'certainly',
#   'oetker',
#   'digital',
#   'support',
#   'group',
#   'companies',
#   'shaping',
#   'digital',
#   'agenda',
#   'share',
#   'competence',
#   'pursue',
#   'digital',
#   'future',
#   'oetker',
#   'group'],
#  ['deep',
#   'understanding',
#   'emerging',
#   'trends',
#   'help',
#   'develop',
#   'new',
#   'business',
#   'fields'],
#  ['ambitious',
#   'goals',
#   'lead',
#   'us',
#   'group',
#   'companies',
#   'along',
#   'exciting',
#   'paths',
#   'share',
#   'passion',
#   'data',
#   'coding',
#   'become',
#   'part',
#   'team',
#   'senior',
#   'data',
#   'engineer'],
#  ['tasks',
#   'future',
#   'develop',
#   'within',
#   'data',
#   'team',
#   'data',
#   'infrastructure',
#   'technological',
#   'backbone',
#   'data',
#   'products',
#   'analytical',
#   'data',
#   'platform',
#   'get',
#   'chance',
#   'use',
#   'broad',
#   'variety',
#   'large',
#   'amounts',
#   'data',
#   'oetker',
#   'group',
#   'companies',
#   'oetker',
#   'digital',
#   '’',
#   'ventures',
#   'enable',
#   'building',
#   'new',
#   'digital',
#   'services',
#   'solve',
#   'businesscritical',
#   'problems',
#   'support',
#   'growth',
#   'data',
#   'team',
#   'help',
#   'build',
#   'team',
#   'setup',
#   'characterized',
#   'autonomy',
#   'trust',
#   'ownership',
#   'alignment',
#   'help',
#   'promoting',
#   'data',
#   'driven',
#   'culture',
#   'work',
#   'closely',
#   'crossfunctional',
#   'product',
#   'teams',
#   'experts',
#   'engineering',
#   'product',
#   'domain',
#   'teams',
#   'challenging',
#   'data',
#   'topics',
#   'products',
#   'mentor',
#   'develop',
#   'junior',
#   'data',
#   'engineers',
#   'requirements',
#   'strengths',
#   'wide',
#   'experience',
#   'agile',
#   'data',
#   'engineering',
#   'space',
#   'solid',
#   'track',
#   'record',
#   'data',
#   'product',
#   'development',
#   'advanced',
#   'knowledge',
#   'python',
#   'sql',
#   'scala',
#   'java',
#   'knowledge',
#   'experience',
#   'designing',
#   'developing',
#   'maintaining',
#   'data',
#   'processing',
#   'systems',
#   'data',
#   'pipelines',
#   'batch',
#   'stream',
#   'processing',
#   'scale',
#   'e.g'],
#  ['using',
#   'spark',
#   'hadoop',
#   'presto',
#   'storm',
#   'flink',
#   'heron',
#   'similar',
#   'knowledge',
#   'docker',
#   'create',
#   'package',
#   'deploy',
#   'run',
#   'applications',
#   'expertise',
#   'operating',
#   'kafka',
#   'scale',
#   'deep',
#   'understanding',
#   'cloud',
#   'data',
#   'platforms',
#   'like',
#   'google',
#   'cloud',
#   'platform',
#   'aws',
#   'azure',
#   'cloud',
#   'stack',
#   'knowhow',
#   'data',
#   'storage',
#   'technologies',
#   'nosql',
#   'rdms',
#   'hive',
#   'hdfs',
#   'mongodb',
#   'cassandra',
#   'experience',
#   'workflow',
#   'management',
#   'systems',
#   'e.g'],
#  ['airflow',
#   'preferably',
#   'oozie',
#   'luigi',
#   'script',
#   'orchestration',
#   'fluent',
#   'english',
#   '–',
#   'german',
#   'plus',
#   'plus',
#   'advanced',
#   'knowledge',
#   'gcp',
#   '’',
#   'bigquery',
#   'pubsub',
#   'dataproc',
#   'cloud',
#   'storage',
#   'etc'],
#  ['benefits',
#   'promise',
#   'berlin',
#   'office',
#   'pursue',
#   'greenfield',
#   'customercentric',
#   'projects',
#   'impact',
#   'oetker',
#   'group',
#   'domestically',
#   'internationally'],
#  ['invite',
#   'voice',
#   'ideas',
#   'explore',
#   'new',
#   'paths',
#   'openminded',
#   'motivated',
#   'teamoriented',
#   'environment'],
#  ['core',
#   'values',
#   'reflect',
#   'familyrun',
#   'business',
#   'committed',
#   'investing',
#   'personal',
#   'professional',
#   'development'],
#  ['interested',
#   'become',
#   'part',
#   'team',
#   'shape',
#   'future',
#   'oetker',
#   'group',
#   'get',
#   'touch',
#   'yvonne',
#   'scheja',
#   'oetker',
#   'digital',
#   'gmbh',
#   'vor',
#   'tag',
#   'weiter',
#   'zur',
#   'bewerbung',
#   'diesen',
#   'job',
#   'melden'],
#  ['responsibilities',
#   'senior',
#   'data',
#   'engineer',
#   'mfx',
#   'take',
#   'responsibility',
#   'flawless',
#   'implementation',
#   'improvement',
#   'future',
#   'data',
#   'processes',
#   'well',
#   'architecture',
#   'actively',
#   'develop',
#   'platform',
#   'cutting',
#   'edge',
#   'technologies',
#   'streamline',
#   'analyze',
#   'data',
#   'flows',
#   'existing',
#   'backend',
#   'infrastructure',
#   'external',
#   'sources',
#   'focussed',
#   'innovative',
#   'cloudbased',
#   'services',
#   'automation',
#   'concepts',
#   'understand',
#   'mentor',
#   'empowers',
#   'colleagues',
#   'methods',
#   'mutual',
#   'learning',
#   'e.g'],
#  ['pair',
#   'programming',
#   'well',
#   'sharing',
#   'best',
#   'practices',
#   'explore',
#   'evaluate',
#   'modern',
#   'technologies',
#   'advance',
#   'products',
#   'address',
#   'infrastructure',
#   'scalability',
#   'performance',
#   'challenges',
#   'skills',
#   'gained',
#   'several',
#   'years',
#   'practical',
#   'experience',
#   'modern',
#   'programmatic',
#   'data',
#   'processing',
#   'analysis',
#   'frameworks',
#   'apache',
#   'spark',
#   'got',
#   'bachelor',
#   '’',
#   'master',
#   '’',
#   'degree',
#   'exhaustive',
#   'knowledge',
#   'python',
#   'scala',
#   'ruby',
#   'plus',
#   'also',
#   'handle',
#   'etl',
#   'processes',
#   'sql',
#   'familiar',
#   'data',
#   'warehousing',
#   'cloudbased',
#   'architecture',
#   'orchestration',
#   'solutions',
#   'airflow',
#   'like',
#   'work',
#   'agile',
#   'environment',
#   'characterised',
#   'international',
#   'team',
#   'intercultural',
#   'exchange',
#   'solutionoriented',
#   'pragmatic',
#   'eye',
#   'detail',
#   'capable',
#   'explaining',
#   'actions',
#   'results',
#   'others',
#   'understandable',
#   'way',
#   'offer',
#   'innovation',
#   'exciting',
#   'diverse',
#   'position',
#   'international',
#   'englishspeaking',
#   'team',
#   'stateoftheart',
#   'technologies',
#   'put',
#   'ideas',
#   'practice',
#   'variety',
#   'wide',
#   'range',
#   'activities',
#   'dynamic',
#   'company',
#   'opportunity',
#   'grow',
#   'tasks',
#   'challenge',
#   'give',
#   'responsibilities',
#   'day',
#   'one',
#   'combine',
#   'short',
#   'decisionmaking',
#   'paths',
#   'plenty',
#   'leeway',
#   'development',
#   'regular',
#   'tech',
#   'meetups',
#   'annual',
#   'conference',
#   'informative',
#   'workshops',
#   'give',
#   'new',
#   'input',
#   'targeted',
#   'training',
#   'courses',
#   'promote',
#   'personal',
#   'development',
#   'team',
#   'colleagues',
#   'waiting',
#   'captivate',
#   'enthusiasm',
#   'team',
#   'spirit',
#   'show',
#   'new',
#   'ultramodern',
#   'office',
#   'potsdamer',
#   'platz',
#   'vor',
#   'tag',
#   'weiter',
#   'zur',
#   'bewerbung',
#   'diesen',
#   'job',
#   'melden'],
#  ['freelancer',
#   'projekt',
#   'big',
#   'data',
#   'engineer',
#   'python',
#   'spark',
#   'aws',
#   'azure',
#   'gcp',
#   'contract',
#   'germany',
#   'remote',
#   'currently',
#   'looking',
#   'big',
#   'data',
#   'engineer',
#   'join',
#   'month',
#   'rolling',
#   'contract',
#   'specialist',
#   'ai',
#   'company',
#   'fully',
#   'remote',
#   'working',
#   'position'],
#  ['please',
#   'see',
#   'looking',
#   'strong',
#   'background',
#   'big',
#   'data',
#   'engineering',
#   'using',
#   'python',
#   'either',
#   'apache',
#   'spark',
#   'scala',
#   'spark',
#   'pyspark',
#   'data',
#   'bricks',
#   'example',
#   'good',
#   'understanding',
#   'aws',
#   'cloud',
#   'ideally',
#   'exposure',
#   'aws',
#   'tech',
#   'lambda',
#   'sqs',
#   'sns',
#   'iam',
#   'glue',
#   'athen',
#   'example'],
#  ['also', 'consider', 'candidates', 'understanding', 'azure', 'gcp'],
#  ['youll',
#   'writing',
#   'complex',
#   'etl',
#   'pipelines',
#   'pythonpyspark',
#   'generate',
#   'reports',
#   'variety',
#   'sources'],
#  ['chance',
#   'get',
#   'stuck',
#   'project',
#   'exciting',
#   'tech',
#   'company',
#   'experienced',
#   'incredible',
#   'growth',
#   'last',
#   'couple',
#   'years',
#   'even',
#   'throughout',
#   'pandemic',
#   'working',
#   'latest',
#   'big',
#   'data',
#   'technologies'],
#  ['need',
#   'right',
#   'candidate',
#   'joined',
#   'asap',
#   'get',
#   'interview',
#   'process',
#   'wrapped',
#   'within',
#   'week',
#   'two'],
#  ['freelancer',
#   'freelance.de',
#   'vor',
#   'tag',
#   'weiter',
#   'zur',
#   'bewerbung',
#   'diesen',
#   'job',
#   'melden'],
#  ['looking',
#   'looking',
#   'solutionoriented',
#   'senior',
#   'data',
#   'engineer',
#   'strong',
#   'communication',
#   'skills',
#   'join',
#   'team'],
#  ['right',
#   'candidate',
#   'become',
#   'owner',
#   'multiple',
#   'projects',
#   'processes',
#   'data',
#   'platform',
#   'help',
#   'us',
#   'build',
#   'state',
#   'art',
#   'data',
#   'processing',
#   'solution'],
#  ['work',
#   'crossfunctional',
#   'featureoriented',
#   'squads',
#   'spotify',
#   'model',
#   'support',
#   'colleagues',
#   'team',
#   'members',
#   'sharing',
#   'knowledge',
#   'pairprogramming',
#   'coding',
#   'review',
#   'sessions'],
#  ['tasks',
#   'model',
#   'etl',
#   'processes',
#   'transform',
#   'sanitise',
#   'data',
#   'schedule',
#   'workflows',
#   'transform',
#   'transition',
#   'data',
#   'apache',
#   'airflow',
#   'connect',
#   'internal',
#   'data',
#   'warehouse',
#   'external',
#   'sources',
#   'assure',
#   'reliability',
#   'consistency',
#   'availability',
#   'data',
#   'flows',
#   'create',
#   'robust',
#   'scalable',
#   'framework',
#   'connecting',
#   'external',
#   'interfaces',
#   'ensure',
#   'data',
#   'science',
#   'models',
#   'algorithms',
#   'run',
#   'production',
#   'level',
#   'support',
#   'data',
#   'science',
#   'backend',
#   'teams',
#   'terms',
#   'sla',
#   'support',
#   'colleagues',
#   'team',
#   'members',
#   'working',
#   'collaboratively',
#   'sharing',
#   'knowledge',
#   'pairprogramming',
#   'coding',
#   'review',
#   'sessions',
#   'report',
#   'directly',
#   'engineering',
#   'manager',
#   'data',
#   'requirements',
#   'years',
#   'professional',
#   'experience',
#   'data',
#   'engineer',
#   'fastpaced',
#   'environment',
#   'master',
#   '’',
#   'degree',
#   'computer',
#   'sciences',
#   'master',
#   '’',
#   'degree',
#   'sciences',
#   'engineering',
#   'physics',
#   'years',
#   'engineering',
#   'exp',
#   'years',
#   'management',
#   'exp',
#   'regardless',
#   'uni',
#   'degree',
#   'years',
#   'engineering',
#   'exp',
#   'years',
#   'management',
#   'experience',
#   'expert',
#   'knowledge',
#   'python',
#   'sql',
#   'ability',
#   'make',
#   'decisions',
#   'ensure',
#   'software',
#   'built',
#   'architecturally',
#   'consistent',
#   'high',
#   'quality',
#   'indepth',
#   'understanding',
#   'data',
#   'structures',
#   'data',
#   'pipelines',
#   'incl'],
#  ['performance',
#   'related',
#   'dependencies',
#   'experience',
#   'data',
#   'integration',
#   'data',
#   'transformation',
#   'database',
#   'schema',
#   'design',
#   'evolution',
#   'experience',
#   'building',
#   'restful',
#   'apis',
#   'e.g'],
#  ['flask',
#   'fastapi',
#   'knowledge',
#   'cicd',
#   'devops',
#   'practices',
#   'experience',
#   'docker',
#   'kubernetes',
#   'plus',
#   'background',
#   'software',
#   'testing',
#   'ability',
#   'communicate',
#   'data',
#   'scientists',
#   'able',
#   'read',
#   'r',
#   'plus',
#   'familiarity',
#   'distributed',
#   'processing',
#   'apache',
#   'sparkapache',
#   'flink',
#   'good',
#   'knowledge',
#   'linux',
#   'shell',
#   'ability',
#   'develop',
#   'data',
#   'pipelinesworkflows',
#   'apache',
#   'airflow',
#   'benefits',
#   'part',
#   'growing',
#   'team',
#   'making',
#   'fast',
#   'decisions',
#   'watch',
#   'ideas',
#   'actions',
#   'come',
#   'fruition'],
#  ['adds',
#   'time',
#   'wellspent',
#   '–',
#   'mere',
#   'billable',
#   'hours',
#   'diversity',
#   'intellectual',
#   'well',
#   'cultural',
#   '–',
#   'join',
#   'welcoming',
#   'international',
#   'team',
#   'smart',
#   'openminded',
#   'people',
#   '’',
#   'easy',
#   'make',
#   'friends',
#   'personal',
#   'development',
#   'plan',
#   'along',
#   'access',
#   'dedicated',
#   'resources',
#   'ensure',
#   'best',
#   'role',
#   'workfamilyfriends',
#   'balance',
#   '–',
#   'step',
#   'treadmill',
#   'feel',
#   'like',
#   'human',
#   'office',
#   'maintaining',
#   'healthy',
#   'balance',
#   'resultsdriven',
#   'work',
#   'environment',
#   'allaround',
#   'wellbeing',
#   'opportunity',
#   'change',
#   'want',
#   'see',
#   'crosslend',
#   'use',
#   'skills',
#   'make',
#   'good',
#   'living',
#   'enhance',
#   'transparency',
#   'financial',
#   'ecosystem',
#   'creative',
#   'ownership',
#   '–',
#   'drive',
#   'business',
#   'forward',
#   'ideas',
#   'launch',
#   'projects',
#   'ground',
#   'see',
#   'inception',
#   'completion',
#   'giving',
#   'input',
#   'galvanising',
#   'colleagues',
#   'bring',
#   'best',
#   'look',
#   'forward',
#   'hearing',
#   'vor',
#   'tagen',
#   'weiter',
#   'zur',
#   'bewerbung',
#   'diesen',
#   'job',
#   'melden'],
#  ['junior',
#   'data',
#   'engineer',
#   'fmd',
#   'interviews',
#   'done',
#   'virtually',
#   'via',
#   'phone',
#   'video',
#   'chat'],
#  ['purpose',
#   'position',
#   'awin',
#   '’',
#   'data',
#   'services',
#   'department',
#   'responsible',
#   'reporting',
#   'across',
#   'business',
#   'providing',
#   'single',
#   'source',
#   'truth'],
#  ['internal',
#   'perspective',
#   'leads',
#   'informed',
#   'business',
#   'decisions',
#   'externally',
#   '’',
#   'able',
#   'provide',
#   'strategic',
#   'insights',
#   'allowing',
#   'clients',
#   'grow',
#   'programmes'],
#  ['junior',
#   'data',
#   'engineer',
#   'fmd',
#   'working',
#   'global',
#   'team',
#   'data',
#   'warehouse',
#   'engineer',
#   'analyst',
#   'reporting',
#   'specialist',
#   'amongst',
#   'big',
#   'data',
#   'engineers',
#   'within',
#   'organization'],
#  ['key',
#   'tasks',
#   'working',
#   'warehouse',
#   'development',
#   'sourcing',
#   'new',
#   'data',
#   'building',
#   'etl',
#   'functions',
#   'delivering',
#   'data',
#   'via',
#   'cubes'],
#  ['also',
#   'able',
#   'work',
#   'minimal',
#   'supervision',
#   'predefined',
#   'standards',
#   'working',
#   'practices'],
#  ['develop',
#   'new',
#   'programs',
#   'functions',
#   'using',
#   'azure',
#   'data',
#   'factory',
#   'azure',
#   'data',
#   'bricks',
#   'python',
#   'scala',
#   'pyspark',
#   'learn',
#   'support',
#   'existing',
#   'projects',
#   'create',
#   'distribute',
#   'data',
#   'using',
#   'azure',
#   'logic',
#   'apps',
#   'ssas',
#   'cube',
#   'power',
#   'bi',
#   'apply',
#   'data',
#   'warehousing',
#   'best',
#   'practices',
#   'modelling',
#   'techniques',
#   'kimball',
#   'star',
#   'schema',
#   'etc'],
#  ['extend',
#   'knowledge',
#   'skills',
#   'terms',
#   'scrum',
#   'agile',
#   'practices',
#   'machine',
#   'learning',
#   'data',
#   'analytics',
#   'whilst',
#   'guide',
#   'general',
#   'expectation',
#   'role',
#   'expect',
#   'position',
#   'evolve',
#   'allowing',
#   'greater',
#   'scope',
#   'gain',
#   'knowledge',
#   'experience',
#   'within',
#   'online',
#   'affiliate',
#   'marketplace'],
#  ['hardworking',
#   'member',
#   'team',
#   'anticipated',
#   'time',
#   'use',
#   'skills',
#   'developed',
#   'role',
#   'form',
#   'solid',
#   'basis',
#   'upward',
#   'progression',
#   'within',
#   'company'],
#  ['skills',
#   'expertise',
#   'bachelor',
#   'degree',
#   'higher',
#   'data',
#   'science',
#   'data',
#   'engineering',
#   'business',
#   'intelligence',
#   'one',
#   'year',
#   'working',
#   'experience',
#   'focus',
#   'data',
#   'engineering',
#   'intelligence',
#   'analytics',
#   'ideally',
#   'big',
#   'data',
#   'environment',
#   'working',
#   'knowledge',
#   'azure',
#   'analytics',
#   'architecture',
#   'azure',
#   'data',
#   'factory',
#   'adf',
#   'azure',
#   'data',
#   'lake',
#   'storage',
#   'adls',
#   'azure',
#   'databricks',
#   'powerbi',
#   'azure',
#   'logic',
#   'apps',
#   'knowledge',
#   'databases',
#   'ideally',
#   'mssql',
#   'mysql',
#   'knowledge',
#   'cloud',
#   'services',
#   'devops',
#   'azure',
#   'aws',
#   'bidata',
#   'analysis',
#   'technologies',
#   'preferred',
#   'essential',
#   'proven',
#   'analysis',
#   'skills',
#   'strong',
#   'team',
#   'player',
#   'comfortable',
#   'working',
#   'distributed',
#   'teams',
#   'strong',
#   'communication',
#   'interaction',
#   'skills',
#   'customerfocused',
#   'service',
#   'attitude',
#   'proactive',
#   'approach',
#   'tasks',
#   'challenges',
#   'getthings',
#   'done',
#   'mentality',
#   'able',
#   'manage',
#   'time',
#   'constructively',
#   'understanding',
#   'project',
#   'process',
#   'management',
#   'competences',
#   'pronounced',
#   'focus',
#   'quality',
#   'delivering',
#   'results',
#   'openmindedness',
#   'willingness',
#   'learn',
#   'andor',
#   'start',
#   'initiatives',
#   'offer',
#   'worklife',
#   'balance',
#   'forefront',
#   'awins',
#   'ethos',
#   'switched',
#   'day',
#   'week',
#   'trial',
#   'basis',
#   'enabling',
#   'employees',
#   'time',
#   'family',
#   'friends',
#   'hobbies',
#   'anything',
#   'else',
#   'paid',
#   'days',
#   'per',
#   'year',
#   'working',
#   'hours',
#   'volunteer',
#   'community',
#   'organisation',
#   'take',
#   'care',
#   'mental',
#   'wellbeing',
#   'access',
#   'various',
#   'mental',
#   'health',
#   'initiatives',
#   'support',
#   'ensure',
#   'safety',
#   'interviews',
#   'conducted',
#   'via',
#   'phone',
#   'video',
#   'calls'],
#  ['global',
#   'business',
#   'offices',
#   'around',
#   'globe',
#   'product',
#   'offering',
#   'fully',
#   'digital',
#   'conducting',
#   'meetings',
#   'interviews',
#   'virtually',
#   'become',
#   'second',
#   'nature',
#   'us'],
#  ['apply', 'could', 'next', 'successful', 'virtual', 'hire'],
#  ['twenty',
#   'years',
#   'experience',
#   'network',
#   'offers',
#   'global',
#   'community',
#   'people',
#   'technology',
#   'business',
#   'intelligence',
#   'insights'],
#  ['matter',
#   'type',
#   'partner',
#   'level',
#   'service',
#   'tools',
#   'business',
#   'needs',
#   'awin',
#   'provides',
#   'solutions',
#   'drive',
#   'sustainable',
#   'growth'],
#  ['part',
#   'axel',
#   'springer',
#   'united',
#   'internet',
#   'groups',
#   'shareasale',
#   'awin',
#   '’',
#   'global',
#   'affiliate',
#   'network',
#   'powered',
#   'offices',
#   'worldwide',
#   'employees',
#   'contributing',
#   'publishers',
#   'advertisers'],
#  ['connecting',
#   'businesses',
#   'customers',
#   'around',
#   'world',
#   'across',
#   'retail',
#   'telecommunications',
#   'travel',
#   'finance',
#   'verticals',
#   'awin',
#   'generated',
#   '€'],
#  ['billion',
#   'revenue',
#   'advertisers',
#   '€',
#   'million',
#   'publishers',
#   'last',
#   'financial',
#   'year'],
#  ['interested', 'joining', 'awin', 'please', 'apply', 'online'],
#  ['apply',
#   'awin',
#   'ag',
#   'vor',
#   'tagen',
#   'weiter',
#   'zur',
#   'bewerbung',
#   'diesen',
#   'job',
#   'melden'],
#  ['checkout',
#   'charlie',
#   'international',
#   'premium',
#   'publisher',
#   'affiliate',
#   'marketing',
#   'part',
#   'media',
#   'group',
#   'rtl'],
#  ['combine',
#   'multimedia',
#   'content',
#   'smart',
#   'content',
#   'distribution',
#   'solutions',
#   'greater',
#   'reach',
#   'awareness'],
#  ['advice',
#   'voucher',
#   'portals',
#   'well',
#   'numerous',
#   'cooperations',
#   'strong',
#   'media',
#   'houses',
#   'including',
#   'spiegel',
#   'ntv',
#   'minuten',
#   'ch',
#   'active',
#   'six',
#   'european',
#   'countries'],
#  ['headquarters', 'berlin', 'office', 'zurich'],
#  ['partner',
#   'companion',
#   'online',
#   'retailers',
#   'specialized',
#   'creating',
#   'customized',
#   'solutions',
#   'individual',
#   'goals',
#   'branding',
#   'new',
#   'customer',
#   'acquisition',
#   'sales',
#   'increase',
#   'many'],
#  ['focus',
#   'versatile',
#   'marketing',
#   'channels',
#   'highquality',
#   'multimedia',
#   'content',
#   'formats',
#   'played',
#   'specific',
#   'target',
#   'groups'],
#  ['keep',
#   'growing',
#   'becoming',
#   'even',
#   'successful',
#   'need',
#   'tasks',
#   'conceptualize',
#   'build',
#   'execute',
#   'project',
#   'endtoend',
#   'concept',
#   'implementation',
#   'delivery',
#   'serving',
#   'expert',
#   'data',
#   'related',
#   'questions',
#   'proactively',
#   'defining',
#   'creating',
#   'standards',
#   'data',
#   'handled',
#   'throughout',
#   'company',
#   'increase',
#   'data',
#   'quality',
#   'accessibility',
#   'implement',
#   'modelling',
#   'dashboards',
#   'reports',
#   'adhoc',
#   'analysis',
#   'work',
#   'bi',
#   'engineers',
#   'development',
#   'product',
#   'team',
#   'provide',
#   'tracking',
#   'data',
#   'based',
#   'services',
#   'solutions',
#   'products',
#   'requirements',
#   'minimum',
#   'years',
#   'experience',
#   'working',
#   'data',
#   'engineer',
#   'business',
#   'intelligence',
#   'engineer',
#   'similar',
#   'role',
#   'solid',
#   'working',
#   'knowledge',
#   'python',
#   'deep',
#   'sqlknowledge',
#   'data',
#   'modulation',
#   'visualization',
#   'tools',
#   'like',
#   'tableau',
#   'understanding',
#   'devops',
#   'solve',
#   'problems',
#   'knowledge',
#   'aws',
#   'cloud',
#   'infrastructure',
#   'knowledge',
#   'web',
#   'tracking',
#   'technologies',
#   'implementation',
#   'furthermore',
#   'naturalborn',
#   'teamplayer',
#   'combined',
#   'ability',
#   'communicate',
#   'technical',
#   'concepts',
#   'nontechnical',
#   'people',
#   'fluent',
#   'english',
#   'language',
#   'skills',
#   'written',
#   'spoken',
#   'german',
#   'plus',
#   'benefits',
#   'feel',
#   'good',
#   'expect',
#   'flat',
#   'hierarchies',
#   'cool',
#   'team',
#   'trusting',
#   'culture',
#   'personal',
#   'professional',
#   'training',
#   'development'],
#  ['also',
#   'enjoy',
#   'free',
#   'drinks',
#   'fresh',
#   'fruits',
#   'regular',
#   'team',
#   'events',
#   'home',
#   'office',
#   'health',
#   'sports',
#   'facilities',
#   'flexible',
#   'working',
#   'hours',
#   'daysholiday'],
#  ['th', 'st', 'december', 'also', 'charlie', 'holiday'],
#  ['company',
#   'pension',
#   'scheme',
#   'equip',
#   'workplace',
#   'modern',
#   'technology',
#   'creative',
#   'rest',
#   'rooms',
#   'well',
#   'table',
#   'soccer',
#   'xbox'],
#  ['office', 'benefits', 'good', 'transport', 'connections', 'dogs', 'welcome'],
#  ['else',
#   'offer',
#   'find',
#   'annesophie',
#   'scherer',
#   'hr',
#   'manager',
#   'tel',
#   'vor',
#   'tagen',
#   'weiter',
#   'zur',
#   'bewerbung',
#   'diesen',
#   'job',
#   'melden'],
#  ['job',
#   'senior',
#   'data',
#   'engineer',
#   'pipeline',
#   'orchestration',
#   'team',
#   'opportunity',
#   'shape',
#   'future',
#   'one',
#   'hottest',
#   'topics',
#   'ecommerce',
#   'today',
#   'tap',
#   'zalando',
#   '’',
#   'biggest',
#   'resource',
#   'data'],
#  ['running',
#   'data',
#   'pipeline',
#   'orchestration',
#   'platform',
#   'enable',
#   'easy',
#   'sustainable',
#   'environment',
#   'steer',
#   'control',
#   'data',
#   'flows'],
#  ['expertise',
#   'needed',
#   'work',
#   'within',
#   'zalandos',
#   'central',
#   'data',
#   'platform',
#   'department',
#   'responsible',
#   'missioncritical',
#   'services',
#   'whole',
#   'zalando',
#   'group',
#   'design',
#   'build',
#   'services',
#   'serve',
#   'analysts',
#   'data',
#   'engineers',
#   'machine',
#   'learning',
#   'pipelines',
#   'zalando',
#   'build',
#   'zalando',
#   'data',
#   'pipeline',
#   'orchestration',
#   'platform',
#   'help',
#   'migrate',
#   'existing',
#   'data',
#   'pipelines',
#   'next',
#   'level',
#   '’',
#   'looking',
#   'years',
#   'professional',
#   'programming',
#   'experience',
#   'python',
#   'java',
#   'scala'],
#  ['knowhow',
#   'continuous',
#   'integration',
#   'continuous',
#   'deployment',
#   'testdriven',
#   'development',
#   'kubernetes',
#   'plus',
#   'mastery',
#   'operating',
#   'data',
#   'infrastructure',
#   'platform',
#   'experience',
#   'working',
#   'large',
#   'open',
#   'source',
#   'projects',
#   'apache',
#   'airflow',
#   'strong',
#   'understanding',
#   'data',
#   'platform',
#   'architecture',
#   'enables',
#   'diverse',
#   'set',
#   'internal',
#   'customers',
#   'work',
#   'efficiently',
#   'data',
#   'ability',
#   'train',
#   'consult',
#   'engineers',
#   'perks',
#   'work',
#   'workplace',
#   'run',
#   'trust',
#   'empowerment',
#   'feedback',
#   'positive',
#   'inspiring',
#   'working',
#   'atmosphere',
#   'competitive',
#   'salary',
#   'employee',
#   'share',
#   'shop',
#   'zalando',
#   'shopping',
#   'discount',
#   'discounts',
#   'external',
#   'partners',
#   'centrally',
#   'located',
#   'offices',
#   'public',
#   'transport',
#   'discounts',
#   'municipality',
#   'services',
#   'great',
#   'equipment',
#   'flexible',
#   'working',
#   'times',
#   'additional',
#   'holidays',
#   'volunteering',
#   'time',
#   'free',
#   'beverages',
#   'fruits',
#   'diverse',
#   'sports',
#   'health',
#   'offerings',
#   'mentoring',
#   'personal',
#   'development',
#   'opportunities',
#   'international',
#   'team',
#   'experts',
# ...
#   'developing',
#   'products',
#   'uncovering',
#   'potential',
#   'technical',
#   'solutions',
#   'range',
#   'realworld',
#   'applications',
#   'confidence',
#   'ability',
#   'interact',
#   'clients',
#   'understand',
#   'problems',
#   'design',
#   'well',
#   'explain',
#   'complex',
#   'technical',
#   'solutions',
#   'excellent',
#   'oral',
#   'written',
#   'communication',
#   'skills',
#   'english',
#   'preferred',
#   'qualifications',
#   'solid',
#   'understanding',
#   'cloud',
#   'infrastructure',
#   'gcp',
#   'aws',
#   'ms',
#   'azure',
#   'experience',
#   'data',
#   'pipeline',
#   'workflow',
#   'management',
#   'tools',
#   'e.g'],
#  ['apache',
#   'beam',
#   'experience',
#   'kubernetes',
#   'highquality',
#   'code',
#   'reviews',
#   'large',
#   'codebase',
#   'preferred',
#   'qualifications',
#   'preferred'],
#  ['none', 'us', 'walked'],
#  ['points',
#   'apply',
#   'definitely',
#   'want',
#   'talk',
#   'working',
#   'merantix',
#   'labs',
#   'please',
#   'keep',
#   'mind',
#   'months',
#   'internship',
#   'position',
#   'however',
#   'ready',
#   'invest',
#   'talent',
#   'keep',
#   'good',
#   'ones',
#   'us',
#   'months',
#   'able',
#   'discuss',
#   'possible',
#   'career',
#   'opportunities',
#   'merantix',
#   'labs'],
#  ['addition',
#   'competitive',
#   'salary',
#   'expect',
#   'following',
#   'engaging',
#   'topics',
#   'merantix',
#   'offers',
#   'unique',
#   'insights',
#   'applied',
#   'machine',
#   'learning',
#   'research',
#   'development',
#   'working',
#   'group',
#   'highly',
#   'talented',
#   'engineers',
#   'entrepreneurs'],
#  ['joining',
#   'dynamic',
#   'young',
#   'company',
#   'interdisciplinary',
#   'team',
#   'encouraged',
#   'pursue',
#   'curiosity',
#   'variety',
#   'topics',
#   'approach',
#   'challenges',
#   'creative',
#   'innovative',
#   'ways'],
#  ['dynamic',
#   'working',
#   'culture',
#   'merantix',
#   'offers',
#   'dynamic',
#   'flexible',
#   'work',
#   'environment'],
#  ['fully',
#   'trustbased',
#   'organization',
#   'believe',
#   'ownership',
#   'work',
#   'personal',
#   'responsibility',
#   'motivation',
#   'people'],
#  ['excellence',
#   'driven',
#   'researchers',
#   'developers',
#   'entrepreneurs',
#   'believe',
#   'create',
#   'committed',
#   'success',
#   'ventures'],
#  ['order',
#   'build',
#   'disruptive',
#   'products',
#   'strive',
#   'outstanding',
#   'quality',
#   'visionary',
#   'ideas',
#   'highperformance',
#   'environments'],
#  ['ethics', 'committed', 'developing', 'ethical', 'ai', 'software'],
#  ['take',
#   'responsibility',
#   'seriously',
#   'committed',
#   'providing',
#   'employees',
#   'customers',
#   'partners',
#   'tools',
#   'need',
#   'develop',
#   'use',
#   'ai',
#   'safely',
#   'accurately',
#   'ethically'],
#  ['“', 'equal', 'opportunity', 'employer', 'value', 'diversity'],
#  ['consider',
#   'applications',
#   'equally',
#   'regardless',
#   'race',
#   'color',
#   'ancestry',
#   'religion',
#   'sex',
#   'national',
#   'origin',
#   'sexual',
#   'orientation',
#   'age',
#   'citizenship',
#   'marital',
#   'status',
#   'disability',
#   'gender',
#   'identity'],
#  ['strongly',
#   'encourage',
#   'individuals',
#   'groups',
#   'traditionally',
#   'underrepresented',
#   'tech',
#   'apply',
#   'help',
#   'immigration',
#   '”',
#   'vor',
#   'tagen',
#   'weiter',
#   'zur',
#   'bewerbung',
#   'diesen',
#   'job',
#   'melden'],
#  ['company',
#   'description',
#   'upday',
#   'europe',
#   '’',
#   'biggest',
#   'news',
#   'app',
#   'fast',
#   'growing',
#   'tech',
#   'media',
#   'company',
#   'joint',
#   'venture',
#   'axel',
#   'springer',
#   'samsung',
#   'electronics'],
#  ['product',
#   'offers',
#   'perfect',
#   'combination',
#   'man',
#   'machine',
#   'algorithms',
#   'inspired',
#   'journalism'],
#  ['offices',
#   'across',
#   'europe',
#   'combine',
#   'editorial',
#   'expertise',
#   'content',
#   'curation',
#   'latest',
#   'personalization',
#   'technologies',
#   'bring',
#   'readers',
#   'stories',
#   'matter'],
#  ['looking',
#   'creative',
#   'committed',
#   'entrepreneurial',
#   'individuals',
#   'helping',
#   'realise',
#   'upday',
#   'vision'],
#  ['become',
#   'innovator',
#   'data',
#   'engineering',
#   'want',
#   'stay',
#   'top',
#   'pioneering',
#   'technology',
#   'big',
#   'data',
#   'implement',
#   'learnings',
#   'team',
#   'player',
#   'first',
#   'experience',
#   'working',
#   'agile',
#   'environment',
#   'keen',
#   'develop',
#   'skills',
#   'team',
#   'interested',
#   'datawarehouse',
#   'structures',
#   'data',
#   'marts',
#   'meet',
#   'business',
#   'operation',
#   'needs',
#   'fascinated',
#   'productionready',
#   'predictioncategorization',
#   'pipelines',
#   'bring',
#   'machine',
#   'learning',
#   'live',
#   'app',
#   'captivated',
#   'data',
#   'manipulation',
#   'trainingevaluation',
#   'solutions',
#   'help',
#   'research',
#   'data',
#   'engineer',
#   'academic',
#   'degree',
#   'computer',
#   'science',
#   'mathematics',
#   'engineering',
#   'equivalent',
#   'practical',
#   'experience',
#   'least',
#   'years',
#   'experience',
#   'data',
#   'engineering',
#   'andor',
#   'machine',
#   'learning',
#   'engineering',
#   'handle',
#   'perfectly',
#   'python',
#   'airflow',
#   'aws',
#   'similar',
#   'dealt',
#   'data',
#   'single',
#   'machine',
#   'handle',
#   'possess',
#   'experience',
#   'it´s',
#   'big',
#   'plus',
#   'snowflake',
#   'snowplow',
#   'spark',
#   'hadoop',
#   'similar',
#   'distributed',
#   'data',
#   'processing',
#   'technologies',
#   'mlops',
#   'technologies',
#   'benefit',
#   'international',
#   'agile',
#   'work',
#   'environment',
#   'wealth',
#   'benefits',
#   'football',
#   'kicker',
#   'table',
#   'tennis',
#   'startup',
#   'gimmicks',
#   'relaxing',
#   'time',
#   'part',
#   'international',
#   'exciting',
#   'revolutionary',
#   'project',
#   'experienced',
#   'colleagues',
#   'different',
#   'departments',
#   'axel',
#   'springer',
#   'tech',
#   'product',
#   'marketing',
#   'journalism',
#   'various',
#   'free',
#   'drinks',
#   'also',
#   'champaign',
#   'special',
#   'occasions',
#   'fresh',
#   'fruit',
#   'twice',
#   'week',
#   'discount',
#   'staff',
#   'restaurant',
#   'work',
#   'creative',
#   'individual',
#   'designed',
#   'open',
#   'office',
#   'heart',
#   'berlin',
#   'flexible',
#   'working',
#   'hours',
#   'suitable',
#   'hardware',
#   'mobile',
#   'working',
#   'like',
#   'laptop',
#   'smartphone',
#   'enable',
#   'ideal',
#   'worklife',
#   'balance',
#   'unlimited',
#   'contract',
#   'reasons',
#   'would',
#   'like',
#   'work',
#   'us',
#   '’',
#   'opportunity',
#   'work',
#   'passionate',
#   'curious',
#   'people',
#   'constant',
#   'strive',
#   'improve',
#   'go',
#   'extra',
#   'mile'],
#  ['strong',
#   'culture',
#   'collegiality',
#   'extraordinary',
#   'team',
#   'spirit',
#   'happy',
#   'share',
#   'proud'],
#  ['provide',
#   'personal',
#   'growing',
#   'support',
#   'blog',
#   'posts',
#   'tech',
#   'talks',
#   'knowledge',
#   'sharing'],
#  ['conduct',
#   'hackathonshackweeks',
#   'every',
#   'willing',
#   'make',
#   'experiments',
#   'constantly',
#   'try',
#   'grow'],
#  ['questions',
#   'answers',
#   'application',
#   'process',
#   'frequently',
#   'asked',
#   'questions',
#   'answers',
#   'found',
#   'faq',
#   'page',
#   'career.axelspringer.comdefaq',
#   'contact',
#   'person',
#   'position',
#   'reference',
#   'number',
#   'michelle',
#   'meitner'],
#  ['licmlihw',
#   'diversity',
#   'essential',
#   'part',
#   'corporate',
#   'culture',
#   'looking',
#   'forward',
#   'receiving',
#   'applications',
#   'regardless',
#   'gender',
#   'nationality',
#   'ethnic',
#   'social',
#   'origin',
#   'religion',
#   'ideology',
#   'disability',
#   'age',
#   'sexual',
#   'orientation',
#   'identity'],
#  ['find',
#   'information',
#   'representation',
#   'severely',
#   'disabled',
#   'axel',
#   'springer',
#   'well',
#   'contact',
#   'details',
#   'career.axelspringer.comenksbv',
#   'additional',
#   'information',
#   'upday',
#   'personalised',
#   'news',
#   'service',
#   'exclusive',
#   'samsung',
#   'devices'],
#  ['combine',
#   'editorial',
#   'expertise',
#   'curation',
#   'latest',
#   'personalisation',
#   'technologies',
#   'bring',
#   'readers',
#   'stories',
#   'matter'],
#  ['vision', 'contribute', 'better', 'informed', 'trustworthy', 'world'],
#  ['upday', 'subsidiary', 'axel', 'springer', 'se', 'headquarters', 'berlin'],
#  ['growing',
#   'fast',
#   'looking',
#   'creative',
#   'committed',
#   'people',
#   'help',
#   'build',
#   'upday',
#   'vision'],
#  ['’',
#   'looking',
#   'join',
#   'young',
#   'dynamic',
#   'international',
#   'team',
#   'full',
#   'fantastic',
#   'talent',
#   'energy',
#   'startup',
#   'stability',
#   'established',
#   'media',
#   'company',
#   'look'],
#  ['preview',
#   'link',
#   'für',
#   'eine',
#   'vorschau',
#   'klicken',
#   'sie',
#   'bitte',
#   'hier'],
#  ['job',
#   'reference',
#   'vor',
#   'tagen',
#   'weiter',
#   'zur',
#   'bewerbung',
#   'diesen',
#   'job',
#   'melden'],
#  ['looking',
#   'right',
#   'people',
#   'join',
#   'wellfunded',
#   'growing',
#   'open',
#   'source',
#   'startup',
#   'help',
#   'us',
#   'continue',
#   'build',
#   'exciting',
#   'technology',
#   'makes',
#   'users',
#   'happy'],
#  ['knime',
#   'provides',
#   'software',
#   'fast',
#   'intuitive',
#   'access',
#   'advanced',
#   'data',
#   'science',
#   'via',
#   'opensource',
#   'knime',
#   'analytics',
#   'platform',
#   'complemented',
#   'commercial',
#   'enterprisegrade',
#   'knime',
#   'server'],
#  ['looking',
#   'data',
#   'engineer',
#   'takes',
#   'care',
#   'internal',
#   'databases',
#   'systems',
#   'konstanz',
#   'berlin',
#   'offices'],
#  ['think',
#   'would',
#   'great',
#   'fit',
#   'would',
#   'like',
#   'learn',
#   'together',
#   'us',
#   'apply',
#   'see',
#   'end',
#   'posting',
#   'make',
#   'application',
#   'even',
#   'relevant'],
#  ['technical', 'background', 'like', 'dealing', 'kinds', 'systems'],
#  ['linux',
#   'administration',
#   'skills',
#   'enjoy',
#   'learning',
#   'new',
#   'technologies'],
#  ['experience',
#   'administering',
#   'postgresql',
#   'databases',
#   'would',
#   'big',
#   'plus'],
#  ['analyzing',
#   'data',
#   'also',
#   'part',
#   'job',
#   'fluent',
#   'sql',
#   'willing',
#   'learn',
#   'put',
#   'knime',
#   'workflows'],
#  ['self',
#   'organized',
#   'able',
#   'overlook',
#   'full',
#   'ecosystem',
#   'data',
#   'multiple',
#   'processes',
#   'involved',
#   'bringing',
#   'data',
#   'system',
#   'providing',
#   'colleagues'],
#  ['’', 'job', 'take', 'care', 'database', 'correct', 'data', 'saved', 'date'],
#  ['multiple', 'scripts', 'run', 'daily', 'basis', 'maintain'],
#  ['care', 'must', 'taken', 'systems', 'updated', 'regularly'],
#  ['also',
#   'good',
#   'overview',
#   'happening',
#   'database',
#   'server',
#   'goto',
#   'person',
#   'related',
#   'questions'],
#  ['maintaining', 'related', 'documentation', 'also', 'part', 'job'],
#  ['course', 'build', 'knime', 'workflows', 'analyze', 'data'],
#  ['transforming',
#   'data',
#   'science',
#   'landscape',
#   'developing',
#   'together',
#   'community',
#   'open',
#   'source',
#   'knime',
#   'analytics',
#   'platform',
#   'lets',
#   'data',
#   'scientists',
#   'mix',
#   'match',
#   'tools',
#   'methods',
#   'want'],
#  ['commercial',
#   'knime',
#   'server',
#   'helps',
#   'enterprises',
#   'integrate',
#   'advanced',
#   'analytics',
#   'operations'],
#  ['knime',
#   'helps',
#   'organizations',
#   'nurture',
#   'new',
#   'user',
#   'populations',
#   'want',
#   'exploit',
#   'benefits',
#   'data',
#   'science',
#   'advanced',
#   'analytics',
#   'remaining',
#   'strongly',
#   'committed',
#   'open',
#   'source'],
#  ['sounds',
#   'like',
#   'challenge',
#   'would',
#   'like',
#   'step',
#   'would',
#   'love',
#   'get',
#   'know'],
#  ['though',
#   'happy',
#   'applicants',
#   'away',
#   '’',
#   'offering',
#   'relocation',
#   'benefits',
#   'position'],
#  ['vor', 'tagen', 'weiter', 'zur', 'bewerbung', 'diesen', 'job', 'melden'],
#  ['hubspots',
#   'business',
#   'intelligence',
#   'bi',
#   'team',
#   'chartered',
#   'making',
#   'hubspot',
#   'smarter',
#   'enabling',
#   'everdeeper',
#   'understanding',
#   'customers'],
#  ['centralized',
#   'reportingonly',
#   'team',
#   'team',
#   'data',
#   'model',
#   'developers',
#   'partner',
#   'business',
#   'leaders',
#   'understand',
#   'nuances',
#   'data',
#   'hubspot',
#   'systems',
#   'well',
#   'provide',
#   'access',
#   'data',
#   'need',
#   'manage',
#   'business',
#   'intelligently'],
#  ['tackle',
#   'hubspots',
#   'complex',
#   'data',
#   'challenges',
#   'manage',
#   'bi',
#   'data',
#   'infrastructure',
#   'provide',
#   'leverage',
#   'network',
#   'business',
#   'analysts',
#   'throughout',
#   'company'],
#  ['get',
#   'work',
#   'best',
#   'breed',
#   'tech',
#   'stack',
#   'includes',
#   'airflow',
#   'snowflake',
#   'dbt',
#   'looker'],
#  ['looking',
#   'place',
#   'youll',
#   'tackle',
#   'big',
#   'problems',
#   'alongside',
#   'talented',
#   'dynamic',
#   'people',
#   'youve',
#   'ever',
#   'worked',
#   'hubspot',
#   'might',
#   'place'],
#  ['role',
#   'youll',
#   'get',
#   'participate',
#   'technical',
#   'execution',
#   'business',
#   'intelligence',
#   'analytics',
#   'related',
#   'projects',
#   'large',
#   'scope',
#   'complexity',
#   'translate',
#   'business',
#   'use',
#   'cases',
#   'set',
#   'technical',
#   'deliverables',
#   'work',
#   'columnar',
#   'databases',
#   'snowflake',
#   'build',
#   'data',
#   'pipelines',
#   'data',
#   'ingestions',
#   'java',
#   'python',
#   'work',
#   'industry',
#   'standard',
#   'etl',
#   'data',
#   'orchestration',
#   'tools',
#   'airflow',
#   'stitch',
#   'fivetran',
#   'build',
#   'scale',
#   'robust',
#   'data',
#   'infrastructure',
#   'serves',
#   'entire',
#   'organization',
#   'looking',
#   'people',
#   'contribute',
#   'codebase',
#   'codebase',
#   'java',
#   'also',
#   'elements',
#   'written',
#   'python',
#   'top',
#   'opensource',
#   'frameworks',
#   'airflow',
#   'dbt'],
#  ['collaborateinfluence', 'across', 'levels', 'organization'],
#  ['remarkable',
#   'building',
#   'relationships',
#   'software',
#   'engineering',
#   'teams',
#   'work',
#   'define',
#   'standards',
#   'best',
#   'practices',
#   'data',
#   'ingestions',
#   'systems'],
#  ['forge',
#   'strong',
#   'partnerships',
#   'product',
#   'managers',
#   'technical',
#   'leads',
#   'teammates',
#   'translating',
#   'business',
#   'requirements',
#   'technical',
#   'vision',
#   'bring',
#   'industry',
#   'best',
#   'practices',
#   'help',
#   'us',
#   'improve',
#   'existing',
#   'data',
#   'infrastructure',
#   'continue',
#   'scale',
#   'growth',
#   'business',
#   'committed',
#   'data',
#   'quality',
#   'security',
#   'privacy',
#   'know',
#   'confidence',
#   'gap',
#   'imposter',
#   'syndrome',
#   'get',
#   'way',
#   'meeting',
#   'spectacular',
#   'candidates',
#   'please',
#   'dont',
#   'hesitate',
#   'apply',
#   '—',
#   'wed',
#   'love',
#   'hear'],
#  ['hubspot',
#   'hubspot',
#   'nyse',
#   'hubs',
#   'leading',
#   'customer',
#   'relationship',
#   'management',
#   'crm',
#   'platform',
#   'provides',
#   'software',
#   'support',
#   'help',
#   'businesses',
#   'grow',
#   'better'],
#  ['build',
#   'marketing',
#   'sales',
#   'service',
#   'website',
#   'management',
#   'products',
#   'start',
#   'free',
#   'scale',
#   'meet',
#   'customers',
#   'needs',
#   'stage',
#   'growth'],
#  ['also',
#   'building',
#   'company',
#   'culture',
#   'empowers',
#   'people',
#   'best',
#   'work'],
#  ['sounds',
#   'like',
#   'something',
#   'youd',
#   'like',
#   'part',
#   'wed',
#   'love',
#   'hear'],
#  ['find',
#   'company',
#   'culture',
#   'hubspot',
#   'culture',
#   'code',
#   'views',
#   'learn',
#   'commitment',
#   'creating',
#   'diverse',
#   'inclusive',
#   'workplace'],
#  ['thanks',
#   'work',
#   'every',
#   'employee',
#   'globally',
#   'hubspot',
#   'named',
#   'best',
#   'place',
#   'work',
#   'glassdoor',
#   'recognized',
#   'awardwinning',
#   'culture',
#   'great',
#   'place',
#   'work',
#   'comparably',
#   'fortune',
#   'entrepreneur',
#   'inc.'],
#  ['headquartered', 'cambridge', 'massachusetts', 'hubspot', 'founded'],
#  ['today',
#   'thousands',
#   'employees',
#   'work',
#   'across',
#   'globe',
#   'hubspot',
#   'offices',
#   'remotely'],
#  ['visit',
#   'careers',
#   'website',
#   'learn',
#   'culture',
#   'opportunities',
#   'hubspot'],
#  ['submitting',
#   'application',
#   'agree',
#   'hubspot',
#   'may',
#   'collect',
#   'personal',
#   'data',
#   'recruiting',
#   'global',
#   'organization',
#   'planning',
#   'related',
#   'purposes'],
#  ['hubspots',
#   'privacy',
#   'notice',
#   'explains',
#   'personal',
#   'information',
#   'may',
#   'process',
#   'may',
#   'process',
#   'personal',
#   'information',
#   'purposes',
#   'processing',
#   'personal',
#   'information',
#   'rights',
#   'exercise',
#   'hubspots',
#   'use',
#   'personal',
#   'information'],
#  ['vor', 'tagen', 'weiter', 'zur', 'bewerbung', 'diesen', 'job', 'melden'],
#  ['seven', 'senders', 'leading', 'delivery', 'platform', 'ship', 'parcels'],
#  ['company',
#   'connects',
#   'shippers',
#   'carrier',
#   'network',
#   'carriers',
#   'europe',
#   'enabling',
#   'use',
#   'excellent',
#   'local',
#   'shipping',
#   'competitive',
#   'advantage'],
#  ...]

# %%
#pipeline.build_vocab(text)
pipeline.train(text)

# %%
text = pipeline.text_field

# %%
skills = pipeline.most_similar_skills(["python"],n_recommendations= 10)

# %%
pipeline.save_model()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-19-e8b25e2cd045> in <module>
# ----> 1 pipeline.save_model()
#
# ~/code/mizzle-toe/find-your-dream-job/fydjob/Word2VecPipeline.py in save_model(self)
#      69
#      70     def save_model(self):
# ---> 71         self.w2v_model.save()
#      72
#      73     def most_similar(self,query,topn = 10):
#
# ~/.pyenv/versions/3.8.6/envs/fydjob/lib/python3.8/site-packages/gensim/models/word2vec.py in save(self, *args, **kwargs)
#    1077         # don't bother storing the cached normalized vectors, recalculable table
#    1078         kwargs['ignore'] = kwargs.get('ignore', ['vectors_norm', 'cum_table'])
# -> 1079         super(Word2Vec, self).save(*args, **kwargs)
#    1080
#    1081     def get_latest_training_loss(self):
#
# TypeError: save() missing 1 required positional argument: 'fname_or_handle'
