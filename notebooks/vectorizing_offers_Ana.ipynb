# %% [markdown]
# # vectorizing job offers

# %% [markdown]
# ## aim
# - cluster job offeres by similarity based on a dictionary of skills
#
# ## outline
# - preprocess doc2vec with full job offers
# - train model
# - test similarity of job descriptions
# - cluster offers (Kmeans, KNN)
#
# ## outcome
# unicorns in a meadow

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from nltk.corpus import stopwords 
from nltk.tokenize import word_tokenize
from nltk.stem import WordNetLemmatizer
import gensim
import joblib
from gensim.models.doc2vec import Doc2Vec, TaggedDocument
from pprint import pprint
import math
import multiprocessing
import gensim.models.doc2vec
import time
import json

# %matplotlib inline

# %%
df = joblib.load('../../../raw_data/processed_data.joblib')

# %%
df.shape
# Out:
# (7859, 14)

# %%
df['tag_language'] = df['tag_language'].fillna(value='en')

# %%
df.head(3)
# Out:
#                         job_title  \
# 0  (Junior) Data Engineer (f/m/x)
# 1
# 2
#
#                                             job_text            company  \
# 0  Customlytics ist die führende App Marketing Be...  Customlytics GmbH
# 1  Responsibilities\n\nAs working student (m/f/x)...         Aroundhome
# 2  Aufgaben\nAls Werkstudent (m/w/d) IT arbeitest...         Aroundhome
#
#   location                                           job_info    query_text  \
# 0   Berlin  (Junior) Data Engineer (f/m/x)\nCustomlytics G...  data science
# 1   Berlin                   Aroundhome6 Bewertungen - Berlin  data science
# 2   Berlin  Aroundhome6 Bewertungen - Berlin\nTeilzeit, Pr...  data science
#
#         source job_link tag_language  reviews  \
# 0  scrape_json      NaN           en      NaN
# 1  scrape_json      NaN           en      NaN
# 2  scrape_json      NaN           de      NaN
#
#                                   job_info_tokenized  \
# 0  [junior, data, engineer, fmx, customlytics, gm...
# 1                  [aroundhome, bewertungen, berlin]
# 2  [aroundhome, bewertungen, berlin, teilzeit, pr...
#
#                                   job_text_tokenized  \
# 0  [customlytics, ist, die, führende, app, market...
# 1  [responsibilities, as, working, student, mfx, ...
# 2  [aufgaben, als, werkstudent, mwd, it, arbeites...
#
#                         job_text_tokenized_titlecase  \
# 0  [Customlytics, ist, die, führende, App, Market...
# 1  [Responsibilities, As, working, student, mfx, ...
# 2  [Aufgaben, Als, Werkstudent, mwd, IT, arbeites...
#
#              job_title_tokenized
# 0  [junior, data, engineer, fmx]
# 1                             []
# 2                             []

# %%
# select english jobs
df_eng = df.copy()
df_eng = df_eng[df_eng['tag_language'] == 'en']
df_eng.reset_index(inplace=True)
df_eng.drop(columns='index', inplace=True)

# %%
df_eng.head()
# Out:
#                         job_title  \
# 0  (Junior) Data Engineer (f/m/x)
# 1
# 2    Full Stack Developer (m/f/d)
# 3
# 4                 Head of Finance
#
#                                             job_text              company  \
# 0  Customlytics ist die führende App Marketing Be...    Customlytics GmbH
# 1  Responsibilities\n\nAs working student (m/f/x)...           Aroundhome
# 2  We’re Phiture: a leading mobile growth consult...              Phiture
# 3  We are 18,000+ employees strong, operating in ...  PRA Health Sciences
# 4  Head of Finance (m/f/d)\nAt Home our mission i...         Home HT GmbH
#
#           location                                           job_info  \
# 0           Berlin  (Junior) Data Engineer (f/m/x)\nCustomlytics G...
# 1           Berlin                   Aroundhome6 Bewertungen - Berlin
# 2  BerlinKreuzberg  Full Stack Developer (m/f/d)\nPhiture - Berlin...
# 3           Berlin                       PRA Health Sciences - Berlin
# 4           Berlin  Head of Finance\nHome HT GmbH2 Bewertungen - B...
#
#      query_text       source job_link tag_language  reviews  \
# 0  data science  scrape_json      NaN           en      NaN
# 1  data science  scrape_json      NaN           en      NaN
# 2  data science  scrape_json      NaN           en      NaN
# 3  data science  scrape_json      NaN           en      NaN
# 4  data science  scrape_json      NaN           en      NaN
#
#                                   job_info_tokenized  \
# 0  [junior, data, engineer, fmx, customlytics, gm...
# 1                  [aroundhome, bewertungen, berlin]
# 2  [full, stack, developer, mfd, phiture, berlink...
# 3                    [pra, health, sciences, berlin]
# 4  [head, of, finance, home, ht, gmbh, bewertunge...
#
#                                   job_text_tokenized  \
# 0  [customlytics, ist, die, führende, app, market...
# 1  [responsibilities, as, working, student, mfx, ...
# 2  [were, phiture, a, leading, mobile, growth, co...
# 3  [we, are, employees, strong, operating, in, mo...
# 4  [head, of, finance, mfd, at, home, our, missio...
#
#                         job_text_tokenized_titlecase  \
# 0  [Customlytics, ist, die, führende, App, Market...
# 1  [Responsibilities, As, working, student, mfx, ...
# 2  [Were, Phiture, a, leading, mobile, growth, co...
# 3  [We, are, employees, strong, operating, in, mo...
# 4  [Head, of, Finance, mfd, At, Home, our, missio...
#
#              job_title_tokenized
# 0  [junior, data, engineer, fmx]
# 1                             []
# 2  [full, stack, developer, mfd]
# 3                             []
# 4            [head, of, finance]

# %%
df_eng.shape
# Out:
# (7547, 14)

# %%
# join strings
def join_strings(text):
    return ' '.join(text)

# %%
# lemmatize
def lemmatize_words(word):
    lemmatizer = WordNetLemmatizer()
    lemmatized = lemmatizer.lemmatize(word)

    return lemmatized

# %%
# remove stopwords
def remove_stopwords(text):

    stop_words = set(stopwords.words('english'))
    word_tokens = word_tokenize(text) 
    text = [w for w in word_tokens if not w in stop_words] 
  
    return text

#['heute', 'weiter', 'zur', 'bewerbung', 'diesen', 'job', 'melden']

# %%
# process text
df_eng['clean'] = df_eng['job_text_tokenized'].apply(join_strings).apply(lemmatize_words)\
    .apply(remove_stopwords)

# %% [markdown]
# ## model doc2vec 1

# %% [markdown]
# Conclusions :)
# - ~ 700 offers - 100 epocs
#     - model performs ok, but tends to cluster according to company
#     - texts with very high similarity (> 0.90) are likely to be duplicated job adds
#     - looks like the model first shows offers based on duplicates, then company, then position (probably because of semantics)
#
#
# - 2500 offers - 150 epocs
#     - still clusters by company
#     - add more data? or try bigrams

# %%
# tag texts
texts = df_eng['clean']
texts_tagged = [TaggedDocument(text, tags=['tag_'+str(tag)]) for tag, text in enumerate(texts)]
texts_tagged[0]
# Out:
# TaggedDocument(words=['customlytics', 'ist', 'die', 'führende', 'app', 'marketing', 'beratungsagentur', 'aus', 'berlin', 'wir', 'bieten', 'consulting', 'und', 'handson', 'support', 'rund', 'um', 'app', 'marketing', 'strategie', 'produktmanagement', 'analytics', 'crm', 'unser', 'team', 'erarbeitet', 'mit', 'unternehmen', 'jeder', 'größe', 'konzepte', 'zur', 'erfolgreichen', 'vermarktung', 'von', 'mobilen', 'apps', 'dabei', 'decken', 'wir', 'nicht', 'nur', 'das', 'gesamte', 'spektrum', 'infrastruktureller', 'marketingthemen', 'ab', 'wir', 'konzipieren', 'planen', 'und', 'steuern', 'sowohl', 'das', 'ui', 'ux', 'design', 'von', 'mobilen', 'apps', 'als', 'auch', 'performance', 'marketing', 'kampagnen', 'für', 'alle', 'app', 'verticals', 'über', 'uns', 'unser', 'data', 'team', 'braucht', 'unterstützung', 'du', 'bist', 'motiviert', 'und', 'von', 'der', 'mobile', 'industry', 'begeistert', 'dann', 'suchen', 'wir', 'dich', 'um', 'die', 'data', 'warehouselösungen', 'für', 'unsere', 'kunden', 'aus', 'der', 'app', 'industrie', 'zu', 'entwickeln', 'und', 'implementieren', 'zusammen', 'mit', 'unserem', 'biteam', 'arbeitest', 'du', 'kundenprojekten', 'der', 'entwicklung', 'implementierung', 'und', 'optimierung', 'von', 'data', 'warehouse', 'projekten', 'du', 'arbeitest', 'hierbei', 'eng', 'mit', 'unserem', 'big', 'data', 'engineer', 'und', 'data', 'analyst', 'zusammen', 'der', 'entwicklung', 'von', 'dashboards', 'und', 'data', 'visualisierungen', 'talent', 'technologieaffinität', 'und', 'eigenverantwortung', 'für', 'deine', 'arbeit', 'zu', 'übernehmen', 'sind', 'die', 'basis', 'unserer', 'teamkultur', 'für', 'uns', 'ist', 'es', 'zweitrangig', 'ob', 'du', 'erst', 'anfang', 'deiner', 'beruflichen', 'laufbahn', 'stehst', 'oder', 'bereits', 'mehrjährige', 'berufserfahrung', 'hast', 'der', 'spirit', 'und', 'die', 'motivation', 'zählen', 'deine', 'aufgaben', 'du', 'berätst', 'unsere', 'teams', 'hinsichtlich', 'der', 'datenanforderungen', 'und', 'bist', 'die', 'schnittstelle', 'zwischen', 'marketingprodukt', 'consultants', 'und', 'dem', 'data', 'engineering', 'bi', 'team', 'du', 'unterstützt', 'bei', 'der', 'analyse', 'von', 'datenströmen', 'unserer', 'kunden', 'aus', 'der', 'mobilen', 'app', 'branche', 'dem', 'aufbereiten', 'von', 'daten', 'und', 'dem', 'entwickeln', 'von', 'datenmodellen', 'du', 'unterstützt', 'unser', 'consultingteam', 'und', 'interne', 'abteilungen', 'als', 'experte', 'bei', 'der', 'vorverarbeitung', 'und', 'auswertung', 'großer', 'datenmengen', 'du', 'versetzt', 'dich', 'die', 'lage', 'deiner', 'externen', 'und', 'internen', 'stakeholder', 'verstehst', 'ihre', 'ziele', 'und', 'anforderungen', 'und', 'übersetzt', 'diese', 'lösungen', 'entwicklung', 'von', 'data', 'warehousingprodukten', 'die', 'unseren', 'wettbewerbsvorteil', 'langfristig', 'sichern', 'und', 'ausbauen', 'dein', 'profil', 'du', 'arbeitet', 'gerne', 'auf', 'englisch', 'mit', 'internationalen', 'kolleginnen', 'du', 'hast', 'erste', 'erfahrung', 'im', 'data', 'oder', 'bo', 'bereich', 'und', 'hast', 'ein', 'abgeschlossenes', 'studium', 'im', 'bereich', 'information', 'systems', 'analytics', 'wirtschaftsinformatik', 'mathematik', 'oder', 'statistik', 'mit', 'affinität', 'zu', 'betriebswirtschaftlichen', 'themen', 'wie', 'zb', 'online', 'marketing', 'du', 'begeisterst', 'dich', 'für', 'die', 'mobile', 'apptechnologiebranche', 'und', 'hast', 'großes', 'interesse', 'technischen', 'lösungen', 'und', 'wie', 'apps', 'unter', 'der', 'haube', 'funktionieren', 'basiswissen', 'sql', 'python', 'und', 'git', 'grundkenntnisse', 'redshift', 'undoder', 'bigquery', 'routinierter', 'umgang', 'mit', 'gängigen', 'anwendungen', 'wie', 'google', 'drive', 'microsoft', 'office', 'mac', 'os', 'und', 'keine', 'scheu', 'sich', 'schnell', 'verschiedene', 'projektmanagement', 'analyse', 'und', 'marketingtools', 'einzuarbeiten', 'du', 'überzeugst', 'mit', 'proaktivität', 'und', 'lösungsorientierter', 'denkweise', 'bonus', 'points', 'agentur', 'undoder', 'startup', 'erfahrung', 'erste', 'erfahrung ...

# %%
# reduced dataset
texts_tagged_small = texts_tagged[:3000]

# %%
data_to_train = texts_tagged_small # texts_tagged_small, texts_tagged

# build vocabulary with CBOW (dm=0)
cores = multiprocessing.cpu_count()
model_dbow = Doc2Vec(documents=data_to_train,
                     dm=0,
                     alpha=0.025,
                     vector_size=len(data_to_train), 
                     min_count=1,
                     workers=cores)

# train the model
model_dbow.train(data_to_train, total_examples=model_dbow.corpus_count, epochs=15)

# %%
model_dbow.save('../../../models/doc2vec_3000_15_epochs')
#joblib.dump(model_dbow, filename='../../../models/doc2vec_3000_20_epochs.joblib' )

# %%
model_dbow.corpus_count

# %% [markdown]
# ### test the model by hand and with copy-pasted text
#
# **test model with texts in the database**

# %%
# load model
model_loaded = Doc2Vec.load('../../../models/doc2vec_3000_20_epochs')

# %%
def similar_jobs(tokenized_job, offers):
    ''' input: tokenized job offers, number of offers 
        returns tags of top x most similar job offers and similarity probabilities
    '''

    # infer vector from text 
    infer_vector = model_loaded.infer_vector(tokenized_job)
    # find similar offers
    similar_documents = model_loaded.docvecs.most_similar([infer_vector], topn = offers)

    return similar_documents

# %%
def print_top_jobs(text, offers=5):
    
    """ input: index of text in dataframe and number of offers we want to see
        prints text of the offers
    """
    
    tags = similar_jobs(text, offers)
    tags = [list(i) for i in tags]
    
    print(f"{tags}\n")
    print(f"{df_eng['job_title'][text_index], df_eng['company'][text_index], df_eng['job_text'][text_index]} \
        \n-------------END------------\n ")
    
    for tag in tags: 
        num = int(tag[0].strip('tag_'))
        
        print(f"{df_eng['job_title'][num], df_eng['company'][num], df_eng['job_text'][num]} \
        \n-------------END------------\n ")

# %%
# print_top_jobs(400, 10) # duplicates 3050; 2020; 400
# #print_top_jobs(5000)

# %% [markdown]
# **test model with copy-pasted job**

# %%
## change case to lower
def to_lower(text):
    return text.lower()

## remove numbers from the corpus
def remove_number(text):
    text = ''.join(word for word in text if not word.isdigit())
    
    return text

## remove special puncutation from text
def remove_punctuation(text):
    for punctuation in string.punctuation:
        text = text.replace(punctuation, '')
    
    return text

# %%
offer = """
You are a Data Scientist and enjoy finding evidence-based solutions to complex scientific questions? You would like to have the opportunity to use your knowledge in a profitable way and to complement your expertise at the same time? You also want start-up atmosphere, a great team and a job in a meaningful industry? Great, then read on!

November is a premium end-of-life brand. With a team of over 70 people, we develop and market innovative retirement products that relieve families of the organizational and financial burdens of a funeral while they are still alive. In the event of death, we organize funerals throughout Germany with an experienced team of morticians, decorators, florists and speakers. Our online portal is now used by circa 700,000 people per month and we count thousands of very satisfied customers.

Your mission:

You help develop an evidence-based model for decision making for our potential customers.
You identify all relevant data sources and prepare data for the specific analysis questions.
You are always on the lookout for new analysis methods especially in the environment of Big Data and Machine Learning.
You perform complex data analyses along our customer journey and develop data-driven algorithms.
You validate and evaluate the collected data and statistical models as well as the resulting recommendations for action that are relevant in various business areas.
You work closely with Novembers management level, as well as with various external subject matter experts, such as university contacts in the field of psychology & statistics.
You abolish the watering can principle in marketing - Through your work it will be possible to address our customers in an individualized and personalized way and to predict what the customer will want in the future.
Your competencies:

Successfully completed studies in data science, physics, engineering, (business) computer science, (business) mathematics, economics, or psychology with a strong quantitative focus and/or statistics
Professional experience in the field of Data Science, as well as hands-on experience with agile projects in all phases up to operational use
Extensive knowledge in the application of statistical methods (e.g. R, Python) as well as in the use of databases (e.g. SQL) and BI/Visualization tools
Knowledge in the application of machine learning, optimization and data mining methods, deep learning and AI (e.g. Python, Keras Tensorflow/Theano)
Outstanding analytical skills, as well as a confident use of data preparation, visualization and analysis methods, especially in the field of machine learning
Your English skills are very good, German skills are advantageous
You've read this far and are still excited? Great, then here comes our offer for you:

Responsible task in an exciting industry that has hardly been digitized so far
Room for independent work
An open corporate culture as well as a passionate team and a lot of fun at work
Attractive salary package and benefits (cooperation with Urban Sports Club, team lunch, etc.)
Home office option and spacious office with foosball in the heart of Berlin
Regular team events, free drinks, snacks and much more
"""

# %%
token_offer = to_lower(offer)
token_offer = remove_number(offer)
token_offer = remove_punctuation(offer)
token_offer = lemmatize_words(offer)
token_offer = remove_stopwords(offer)
#offer
token_offer[:]
# Out:
# ['You',
#  'Data',
#  'Scientist',
#  'enjoy',
#  'finding',
#  'evidence-based',
#  'solutions',
#  'complex',
#  'scientific',
#  'questions',
#  '?',
#  'You',
#  'would',
#  'like',
#  'opportunity',
#  'use',
#  'knowledge',
#  'profitable',
#  'way',
#  'complement',
#  'expertise',
#  'time',
#  '?',
#  'You',
#  'also',
#  'want',
#  'start-up',
#  'atmosphere',
#  ',',
#  'great',
#  'team',
#  'job',
#  'meaningful',
#  'industry',
#  '?',
#  'Great',
#  ',',
#  'read',
#  '!',
#  'November',
#  'premium',
#  'end-of-life',
#  'brand',
#  '.',
#  'With',
#  'team',
#  '70',
#  'people',
#  ',',
#  'develop',
#  'market',
#  'innovative',
#  'retirement',
#  'products',
#  'relieve',
#  'families',
#  'organizational',
#  'financial',
#  'burdens',
#  'funeral',
#  'still',
#  'alive',
#  '.',
#  'In',
#  'event',
#  'death',
#  ',',
#  'organize',
#  'funerals',
#  'throughout',
#  'Germany',
#  'experienced',
#  'team',
#  'morticians',
#  ',',
#  'decorators',
#  ',',
#  'florists',
#  'speakers',
#  '.',
#  'Our',
#  'online',
#  'portal',
#  'used',
#  'circa',
#  '700,000',
#  'people',
#  'per',
#  'month',
#  'count',
#  'thousands',
#  'satisfied',
#  'customers',
#  '.',
#  'Your',
#  'mission',
#  ':',
#  'You',
#  'help',
#  'develop',
#  'evidence-based',
#  'model',
#  'decision',
#  'making',
#  'potential',
#  'customers',
#  '.',
#  'You',
#  'identify',
#  'relevant',
#  'data',
#  'sources',
#  'prepare',
#  'data',
#  'specific',
#  'analysis',
#  'questions',
#  '.',
#  'You',
#  'always',
#  'lookout',
#  'new',
#  'analysis',
#  'methods',
#  'especially',
#  'environment',
#  'Big',
#  'Data',
#  'Machine',
#  'Learning',
#  '.',
#  'You',
#  'perform',
#  'complex',
#  'data',
#  'analyses',
#  'along',
#  'customer',
#  'journey',
#  'develop',
#  'data-driven',
#  'algorithms',
#  '.',
#  'You',
#  'validate',
#  'evaluate',
#  'collected',
#  'data',
#  'statistical',
#  'models',
#  'well',
#  'resulting',
#  'recommendations',
#  'action',
#  'relevant',
#  'various',
#  'business',
#  'areas',
#  '.',
#  'You',
#  'work',
#  'closely',
#  'Novembers',
#  'management',
#  'level',
#  ',',
#  'well',
#  'various',
#  'external',
#  'subject',
#  'matter',
#  'experts',
#  ',',
#  'university',
#  'contacts',
#  'field',
#  'psychology',
#  '&',
#  'statistics',
#  '.',
#  'You',
#  'abolish',
#  'watering',
#  'principle',
#  'marketing',
#  '-',
#  'Through',
#  'work',
#  'possible',
#  'address',
#  'customers',
#  'individualized',
#  'personalized',
#  'way',
#  'predict',
#  'customer',
#  'want',
#  'future',
#  '.',
#  'Your',
#  'competencies',
#  ':',
#  'Successfully',
#  'completed',
#  'studies',
#  'data',
#  'science',
#  ',',
#  'physics',
#  ',',
#  'engineering',
#  ',',
#  '(',
#  'business',
#  ')',
#  'computer',
#  'science',
#  ',',
#  '(',
#  'business',
#  ')',
#  'mathematics',
#  ',',
#  'economics',
#  ',',
#  'psychology',
#  'strong',
#  'quantitative',
#  'focus',
#  'and/or',
#  'statistics',
#  'Professional',
#  'experience',
#  'field',
#  'Data',
#  'Science',
#  ',',
#  'well',
#  'hands-on',
#  'experience',
#  'agile',
#  'projects',
#  'phases',
#  'operational',
#  'use',
#  'Extensive',
#  'knowledge',
#  'application',
#  'statistical',
#  'methods',
#  '(',
#  'e.g',
#  '.',
#  'R',
#  ',',
#  'Python',
#  ')',
#  'well',
#  'use',
#  'databases',
#  '(',
#  'e.g',
#  '.',
#  'SQL',
#  ')',
#  'BI/Visualization',
#  'tools',
#  'Knowledge',
#  'application',
#  'machine',
#  'learning',
#  ',',
#  'optimization',
#  'data',
#  'mining',
#  'methods',
#  ',',
#  'deep',
#  'learning',
#  'AI',
#  '(',
#  'e.g',
#  '.',
#  'Python',
#  ',',
#  'Keras',
#  'Tensorflow/Theano',
#  ')',
#  'Outstanding',
#  'analytical',
#  'skills',
#  ',',
#  'well',
#  'confident',
#  'use',
#  'data',
#  'preparation',
#  ',',
#  'visualization',
#  'analysis',
#  'methods',
#  ',',
#  'especially',
#  'field',
#  'machine',
#  'learning',
#  'Your',
#  'English',
#  'skills',
#  'good',
#  ',',
#  'German',
#  'skills',
#  'advantageous',
#  'You',
#  "'ve",
#  'read',
#  'far',
#  'still',
#  'excited',
#  '?',
#  'Great',
#  ',',
#  'comes',
#  'offer',
#  ':',
#  'Responsible',
#  'task',
#  'exciting',
#  'industry',
#  'hardly',
#  'digitized',
#  'far',
#  'Room',
#  'independent',
#  'work',
#  'An',
#  'open',
#  'corporate',
#  'culture',
#  'well',
#  'passionate',
#  'team',
#  'lot',
#  'fun',
#  'work',
#  'Attractive',
#  'salary',
#  'package',
#  'benefits',
#  '(',
#  'cooperation',
#  'Urban',
#  'Sports',
#  'Club',
#  ',',
#  'team',
#  'lunch',
#  ',',
#  'etc',
#  '.',
#  ')',
#  'Home',
#  'office',
#  'option',
#  'spacious',
#  'office',
#  'foosball',
#  'heart',
#  'Berlin',
#  'Regular',
#  'team',
#  'events',
#  ',',
#  'free',
#  'drinks',
#  ',',
#  'snacks',
#  'much']

# %%
infer_vector = model_loaded.infer_vector(token_offer)
infer_vector
# Out:
# array([ 0.21694319, -0.18454333,  0.0015175 , ..., -0.141679  ,
#         0.18379204,  0.06664702], dtype=float32)

# %%
similar_documents = model_loaded.docvecs.most_similar([infer_vector], topn = 5)

# %%
tags = similar_documents
tags = [list(i) for i in tags]

print(f"{tags}\n")
# print(f"{df_eng['job_title'][text_index], df_eng['company'][text_index], df_eng['job_text'][text_index]} \
#     \n-------------END------------\n ")

for tag in tags: 
    num = int(tag[0].strip('tag_'))

    print(f"{df_eng['job_title'][num], df_eng['company'][num], df_eng['job_text'][num]} \
    \n-------------END------------\n ")
# Out:
# [['tag_511', 0.9291380047798157], ['tag_689', 0.9210711717605591], ['tag_718', 0.5408948659896851], ['tag_559', 0.5356857776641846], ['tag_1', 0.5032567381858826]]
#
# ('Data Scientist (m/w/d)', 'November', "You are a Data Scientist and enjoy finding evidence-based solutions to complex scientific questions? You would like to have the opportunity to use your knowledge in a profitable way and to complement your expertise at the same time? You also want start-up atmosphere, a great team and a job in a meaningful industry? Great, then read on!\nNovember is a premium end-of-life brand. With a team of over 70 people, we develop and market innovative retirement products that relieve families of the organizational and financial burdens of a funeral while they are still alive. In the event of death, we organize funerals throughout Germany with an experienced team of morticians, decorators, florists and speakers. Our online portal is now used by circa 700,000 people per month and we count thousands of very satisfied customers.\nYour mission:\nYou help develop an evidence-based model for decision making for our potential customers.\nYou identify all relevant data sources and prepare data for the specific analysis questions.\nYou are always on the lookout for new analysis methods especially in the environment of Big Data and Machine Learning.\nYou perform complex data analyses along our customer journey and develop data-driven algorithms.\nYou validate and evaluate the collected data and statistical models as well as the resulting recommendations for action that are relevant in various business areas.\nYou work closely with Novembers management level, as well as with various external subject matter experts, such as university contacts in the field of psychology & statistics.\nYou abolish the watering can principle in marketing - Through your work it will be possible to address our customers in an individualized and personalized way and to predict what the customer will want in the future.\nYour competencies:\nSuccessfully completed studies in data science, physics, engineering, (business) computer science, (business) mathematics, economics, or psychology with a strong quantitative focus and/or statistics\nProfessional experience in the field of Data Science, as well as hands-on experience with agile projects in all phases up to operational use\nExtensive knowledge in the application of statistical methods (e.g. R, Python) as well as in the use of databases (e.g. SQL) and BI/Visualization tools\nKnowledge in the application of machine learning, optimization and data mining methods, deep learning and AI (e.g. Python, Keras Tensorflow/Theano)\nOutstanding analytical skills, as well as a confident use of data preparation, visualization and analysis methods, especially in the field of machine learning\nYour English skills are very good, German skills are advantageous\nYou've read this far and are still excited? Great, then here comes our offer for you:\nResponsible task in an exciting industry that has hardly been digitized so far\nRoom for independent work\nAn open corporate culture as well as a passionate team and a lot of fun at work\nAttractive salary package and benefits (cooperation with Urban Sports Club, team lunch, etc.)\nHome office option and spacious office with foosball in the heart of Berlin\nRegular team events, free drinks, snacks and much more\nAll you have to do in the first step is to send us your application documents. We look forward to receiving a short your resume and your references.\nDo you have any questions? Feel free to contact Alex from our HR team.\nArt der Stelle: Vollzeit\nLeistungen:\nBetriebliche Altersvorsorge\nBetriebliche Weiterbildung\nBetriebsfeiern\nFlexible Arbeitszeiten\nHomeoffice\nKostenlose Getränke\nKostenloses oder Vergünstigtes Essen\nBerufserfahrung:\nData Science or similar : 3 Jahre (Erforderlich)\nSprache:\nEnglish (Erforderlich)\nvor 1 Tag\nDiesen Job melden")
# -------------END------------
#
# ('', 'November', "You are a Data Scientist and enjoy finding evidence-based solutions to complex scientific questions? You would like to have the opportunity to use your knowledge in a profitable way and to complement your expertise at the same time? You also want start-up atmosphere, a great team and a job in a meaningful industry? Great, then read on!\nNovember is a premium end-of-life brand. With a team of over 70 people, we develop and market innovative retirement products that relieve families of the organizational and financial burdens of a funeral while they are still alive. In the event of death, we organize funerals throughout Germany with an experienced team of morticians, decorators, florists and speakers. Our online portal is now used by circa 700,000 people per month and we count thousands of very satisfied customers.\nYour mission:\nYou help develop an evidence-based model for decision making for our potential customers.\nYou identify all relevant data sources and prepare data for the specific analysis questions.\nYou are always on the lookout for new analysis methods especially in the environment of Big Data and Machine Learning.\nYou perform complex data analyses along our customer journey and develop data-driven algorithms.\nYou validate and evaluate the collected data and statistical models as well as the resulting recommendations for action that are relevant in various business areas.\nYou work closely with Novembers management level, as well as with various external subject matter experts, such as university contacts in the field of psychology & statistics.\nYou abolish the watering can principle in marketing - Through your work it will be possible to address our customers in an individualized and personalized way and to predict what the customer will want in the future.\nYour competencies:\nSuccessfully completed studies in data science, physics, engineering, (business) computer science, (business) mathematics, economics, or psychology with a strong quantitative focus and/or statistics\nProfessional experience in the field of Data Science, as well as hands-on experience with agile projects in all phases up to operational use\nExtensive knowledge in the application of statistical methods (e.g. R, Python) as well as in the use of databases (e.g. SQL) and BI/Visualization tools\nKnowledge in the application of machine learning, optimization and data mining methods, deep learning and AI (e.g. Python, Keras Tensorflow/Theano)\nOutstanding analytical skills, as well as a confident use of data preparation, visualization and analysis methods, especially in the field of machine learning\nYour English skills are very good, German skills are advantageous\nYou've read this far and are still excited? Great, then here comes our offer for you:\nResponsible task in an exciting industry that has hardly been digitized so far\nRoom for independent work\nAn open corporate culture as well as a passionate team and a lot of fun at work\nAttractive salary package and benefits (cooperation with Urban Sports Club, team lunch, etc.)\nHome office option and spacious office with foosball in the heart of Berlin\nRegular team events, free drinks, snacks and much more\nAll you have to do in the first step is to send us your application documents. We look forward to receiving a short your resume and your references.\nDo you have any questions? Feel free to contact Alex from our HR team.\nArt der Stelle: Vollzeit\nLeistungen:\nBetriebliche Altersvorsorge\nBetriebliche Weiterbildung\nBetriebsfeiern\nFlexible Arbeitszeiten\nHomeoffice\nKostenlose Getränke\nKostenloses oder Vergünstigtes Essen\nBerufserfahrung:\nData Science or similar : 3 Jahre (Erforderlich)\nSprache:\nEnglish (Erforderlich)\nHeute\nDiesen Job melden")
# -------------END------------
#
# ('Business Intelligence Data Scientist (m/w/d)', 'adviqo GmbH', 'Job summary\nAs Business Intelligence Data Scientist you will be part of an open-minded Business Intelligence team. We are passionate about handling data and numbers and not only theoretically understand the latest big data and machine learning technologies, but also applying them practically. We live, communicate and promote a data-driven approach at adviqo.\nYour challenges\nYou will create business intelligence analyses (predictive analytics, machine learning, deep learning) for the various business processes of adviqo\nIn close cooperation with different business departments you are responsible for the data visualization\nYou are able to construe the results accurately and conduct concrete recommendations for the business units and the management\nYou manage and control Data Science projects\nHow you can inspire us\nYou have a university degree in computer science, physics, (business) mathematics or a comparable qualification\nYou have extensive knowledge of AI and Data Mining-Methods and applied statistics (incl. multivariate analysis methods, regression analysis or machine learning)\nIdeally, you have first practical experience in the areas of BI Reporting, BI Analytics, the respective software products and basic statistics knowledge\nThis experience is complemented by profound knowledge in data modelling, data management (incl. ETL skills), database technologies and Big Data\nYou are passionate about data, analysis and visualization\nYou have excellent communication skills, a target-oriented working method and a strong analytical and conceptional ability\nYou speak English or German\nLocation & Benefits\nOur office is located at Berlin, S- & U-Bahn station Jungfernheide. You reach us with the circle line or regional train which connects the Berlin central station in under 5 minutes. You work in a brand-new office directly on the riverside with gaming and chilling areas, basketball court, table tennis, Thirsty-Thursdays and proper coffee. Join us for an after-work beer on the roof terrace. We offer you many other perks.\nSounds thrilling? We are looking forward to your application including earliest start date and salary expectations!\nvor 25 Tagen\n- Weiter zur Bewerbung\nDiesen Job melden')
# -------------END------------
#
# ('Business Intelligence Data Scientist (m/w/d)', 'adviqo GmbH', 'Job summary\nAs Business Intelligence Data Scientist you will be part of an open-minded Business Intelligence team. We are passionate about handling data and numbers and not only theoretically understand the latest big data and machine learning technologies, but also applying them practically. We live, communicate and promote a data-driven approach at adviqo.\nYour challenges\nYou will create business intelligence analyses (predictive analytics, machine learning, deep learning) for the various business processes of adviqo\nIn close cooperation with different business departments you are responsible for the data visualization\nYou are able to construe the results accurately and conduct concrete recommendations for the business units and the management\nYou manage and control Data Science projects\nHow you can inspire us\nYou have a university degree in computer science, physics, (business) mathematics or a comparable qualification\nYou have extensive knowledge of AI and Data Mining-Methods and applied statistics (incl. multivariate analysis methods, regression analysis or machine learning)\nIdeally, you have first practical experience in the areas of BI Reporting, BI Analytics, the respective software products and basic statistics knowledge\nThis experience is complemented by profound knowledge in data modelling, data management (incl. ETL skills), database technologies and Big Data\nYou are passionate about data, analysis and visualization\nYou have excellent communication skills, a target-oriented working method and a strong analytical and conceptional ability\nYou speak English or German\nLocation & Benefits\nOur office is located at Berlin, S- & U-Bahn station Jungfernheide. You reach us with the circle line or regional train which connects the Berlin central station in under 5 minutes. You work in a brand-new office directly on the riverside with gaming and chilling areas, basketball court, table tennis, Thirsty-Thursdays and proper coffee. Join us for an after-work beer on the roof terrace. We offer you many other perks.\nSounds thrilling? We are looking forward to your application including earliest start date and salary expectations!\nvor 26 Tagen\n- Weiter zur Bewerbung\nDiesen Job melden')
# -------------END------------
#
# ('', 'Aroundhome', 'Responsibilities\n\nAs working student (m/f/x) IT you work in close collaboration with our data team and get comprehensive insights into the daily business of our IT department\nYou are a full member of our cross-functional scrum team and contribute directly to the further development of our central database (aka Data Lake, Business Object Layer, Datamarts)\nYou support our internal stakeholders together with our data analyst by building meaningful dashboards, analyses, as well as forecasts and therefore ensure efficient marketing control\nYou help to design as well as to optimize processes and create substantial reports to track the effectiveness of the implemented measures\nSkills\n\nYou are studying Data Science, Business Informatics, or equivalent and have a strong interest in Data as well as IT topics\nYou have a good mix of organizational skills and an affinity for numbers, work in a structured as well as independent manner and love to deep dive into complex topics\nYou have a solid knowledge of data science as well as statistics in eCommerce, IT infrastructure (API, DBMS, ETL), and ideally first experiences with tools such as Tableau, Big Query or AWS Services as well as SQL and Python\nYou impress with your strong communication skills and are an absolute team player\nWhat we offer\n\nYour opportunity: An exciting, varied position with the possibility to actively shape the development and advancement of our IT department.\nYour development: An extremely steep learning curve through challenging tasks as well as excellent opportunities to take over and develop your career.\nYour working conditions: Flexible working hours tailored to your needs, which are always compatible with your studies\nYour working atmosphere: An open corporate culture and an international team that is already looking forward to meeting you : -)\nGerade geschaltet\n- Weiter zur Bewerbung\nDiesen Job melden')
# -------------END------------

# %% [markdown]
# ## improve the model 1
# Steps:
# - filter out all words not in dictionary
# - train model
# - get output and see if it's better

# %%
# import dictionary

with open('../fydjob/data/dicts/skills_dict.json') as json_file:
    dictionary = json.load(json_file)

# collapse dictionary into list

#skills_list =

# %%
skills_list = []

for value in dictionary.items():
    print(value[1])
# Out:
# business
# knowledge
# programming
# soft_skills
# tech_adjectives

# %%
# filter tokens for skills

# %%
# train model # train_model.train(alldocs, total_examples=len(alldocs), epochs=epochs, start_alpha=0.025, end_alpha=0.001)

# %%
# save model

# %%
# test model

# %% [markdown]
# ## Improve the model - 2
#
# - try bigrams instead ot unigrams

# %%
texts_small = df_eng['clean'][:2500]

# %%
texts_small.head()

# %%
from gensim.models import Phrases
from gensim.models.phrases import Phraser
from gensim import models

# %%
bigram = Phrases(texts_small, min_count=1, threshold=2, delimiter=b' ')

bigram_phraser = Phraser(bigram)

# %%
bigram_token = []
for sent in texts_small:
    bigram_token.append(bigram_phraser[sent])
    
bigram_token[:20]
